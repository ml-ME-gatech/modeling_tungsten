# %% [markdown]
# ### Isothermal JMAK Function
# $$
# X(t,T) = 1 - \exp{-b(T)^n(t - t_{inc}(T))^n}
# t_{inc}= A_1 \exp{B_1/T} \qquad b(T)  = A_2 \exp{B_2/T} \\
# a_1 = \ln{A_1},a_2 = \ln{A_2}
# $$
#
# ### Nonisothermal JMAK Function
# $$
# Y(t)  = \begin{cases}
# 0 \qquad & t \leq t_0 \\
# Y^{\dagger}(t - t_0) \qquad & t > t_0 \\
# \end{cases}
# $$
#
# $$
# \begin{matrix}
# t_0 = \rho^{-1}(1) \qquad \rho = \int \frac{d \tau}{t_{inc}(T(\tau))}\\
# Y^{\dagger}(t) = 1 - \exp{\left\lbrace - \left( \int b(T(\tau)) d\tau \right)^n  \right\rbrace }
# \end{matrix}
# $$
#
# ### Inverted Isothermal JMAK function
# $$
# t_{iso}(X = X^*,T) = t_{inc}(T) + \frac{1}{b(T)}\left(-\ln{(1 - X^*)}\right)^{1/n}
# $$
#
# Clearly for every $X^*$ and specified operating time $\tau_{op}$ we can find a $T_{iso}$ such that $t_{iso}(X = X^*,T = T_{iso}) = \tau_{op}$
#
# We want to examine how transient events can impact the computed $T_{iso}$.
#
# ## Recrystallization
#
# ### Inverted Non-isothermal JMAK Function
# $$
# t_{a}(X = X^*,T) = \tau_{a,inc} + \tau_{a,rx} \\
# $$
#
# where $\tau_{a,inc}$ solves:
#
# $$
# \int_{0}^{\tau_{a,inc}} \frac{dt}{t_{inc}(T(t))} = 1
# $$
#
# and $\tau_{a,rx}$ solves
# $$
# \left(-\ln{(1 - X^*)}\right)^{1/n} = \int_{0}^{\tau_{a,rx}} b(T(t)) dt
# $$
#
#
# Let $\mathcal{T}_{inc} = \{t: 0 \leq t \leq \tau_{a,inc}\}$ and similarly $\mathcal{T}_{rx} = \{t: 0 \leq t \leq \tau_{a,rx}\}$. Assume that each of these sets contains $N_{d,inc}$ and $N_{d,rx}$ sets each with
#
# $D_i = {s_i \leq t \leq t + \tau_r}, i = 1,...N_{d,\cdot}$ and further that $s_{i} \geq s_{i-1} + \tau_r \forall i = 2,... N_{d,\cdot}$ and $0 < s_{i} < \tau_{op} - \tau_r \forall i$. define $\mathcal{T}^d_{inc} = \cup_{i = 1}^{N_{d,inc}} D_i$ and a similar defintion for $\mathcal{T}_{rx}^d$ for the $D_i$ during recrystallization. The complements are $\mathcal{T}_{inc}^s = \mathcal{T}_{inc} \backslash \mathcal{T}_{inc}^d$ and $\mathcal{T}_{rx}^s = \mathcal{T}_{rx} \backslash \mathcal{T}_{rx}^d$
#
# On each $D_i$ the temperature profile may be written as $T_r(t;T_a) = T_{a} + \Delta T_r(t)$ and assume that the profile is $C^1(\mathcal{T}_{inc})$ and $C^1(\mathcal{T}_{rx})$. on $\mathcal{T}_{inc}^s$ and $\mathcal{T}_{rx}^s$ the temperature is constant at $T_{a}$. The _goal_ is to solve for $T_a$.
#
# Notice that the ordering of the sets, and their spacing does not impact the overall integral evalutions in the non-isothermal jmak equations. In fact, we may write:
#
# $$
# \int_{0}^{\tau_{a,rx}} b(T(t)) dt = \int_{0}^{\tau_{a,rx} - N_{d,rx} \tau_{a,rx}} b(T_a) dt + N_d \int_{0}^{\tau_r} b(T_r(t;T_a)) dt = \left(\tau_{a,rx} - N_{d,rx} \tau_{a,rx} \right) b(T_a) + N_d \int_{0}^{\tau_r} b(T_r(t;T_a)) dt \\
# $$
#
# and
#
# $$
# \int_{0}^{\tau_{a,inc}} \frac{dt}{t_{inc}(T(t))} = \frac{\tau_{a,inc} - N_{d,inc}\tau_r}{t_{inc}(T_a)} + N_{d,inc} \tau_r \int_{0}^{\tau_r} \frac{1}{t_{inc}(T_r(t; T_a))} dt
# $$
#
# with the important implication being that we only have to evaluate the integrals for a single disturbance temperature profile, not over the whole set of time.
#
# $$
# \begin{matrix}
# \tau_{op} = \tau_{a,inc} + \tau_{a,rx}  \qquad \text{equivalency to the isothermal case} \\
# N_d = N_{d,inc} + N_{d,rx} \qquad \text{total number of cycles} \\
# \frac{N_{d,inc}}{N_{d,rx}} = \alpha \lceil \frac{\tau_{a,inc}}{\tau_{a,rx}} \rceil \qquad \text{approximately evenly distributed cycles.}
# \end{matrix}
# $$
# The intent is to specify the temperature  profile as mostly constant with some number $N_{d}$ of transient/disturbance periods and see how $T_a$ is effected relative to $T_{iso}$ as $N_{d}$ increases.
#
#
# The parameters  $a_1,B_2,a_2,B_2,n$, are estiamted from data and specified.
#
# The parameters $X^*,\tau_{op}$ are known and specified
#
# I approximate and specify $\Delta T_r(t), \tau_r$,
#
# I want to vary $\tau_{op}$ and $N_d$ and study the effect they have. $\alpha$ is sort-of a nuisance parameter because the effect of the disturbance temperatures may be somewhat different for the incubation and recrystallization time periods.

# %%
import jax
import jax.numpy as jnp
from jax import jit, grad,vmap
from jaxopt import Broyden, Bisection
from dataclasses import dataclass
from typing import Tuple
from typing import Callable
import warnings 

__all__ = [
    "JMAKParams",
    "invert_isothermal_T",
    "solve_Ta_and_tau_inc",
]


@dataclass
class JMAKParams:
    """Physical and operational parameters for the non‑isothermal JMAK solver."""

    # Kinetic parameters (Arrhenius form)
    n: float   # Avrami exponent
    a1: float  # ln A1 for growth
    B1: float  # activation term for growth (K)
    a2: float  # ln A2 for  incubation
    B2: float  # activation term for incubation (K)

    # Target & schedule
    X_star: float  # required transformed fraction (0 < X_star < 1)
    tau_op: float  # total operation time (s)

    # Disturbance specification
    tau_r: float         # duration of a single disturbance window (s)
    N_d: int
    alpha: float
    deltaT_r: jnp.ndarray  # temperature *offset* profile for one window (shape (Nt,))
    t: jnp.ndarray         # time profile for one window (shape (Nt,))

    # Numerical safety bounds
    Tmin: float = 600.0   # K
    Tmax: float = 4000.0  # K

    # ---------- kinetic helpers ----------
    def t_inc(self, T: jnp.ndarray) -> jnp.ndarray:
        """Incubation time (s)."""
        return jnp.exp(self.a2 + self.B2 / T)

    def b(self, T: jnp.ndarray) -> jnp.ndarray:
        """Growth‑rate coefficient (1/s^n)."""
        return jnp.exp(self.a1 + self.B1 / T)

    @property
    def ln_term(self) -> jnp.ndarray:
        """Natural log term for the recrystallization rate equation."""
        return (-jnp.log1p(-self.X_star)) ** (1.0 / self.n)
# -----------------------------------------------------------
# One‑window integrals (re‑evaluated each time Ta changes)
# -----------------------------------------------------------

def _single_window_integrals(p: JMAKParams):
    """Return jit‑compiled integrators for one disturbance window."""

    if p.tau_r == 0.0 or p.N_d == 0 or p.deltaT_r is None:
        # Degenerate case – no disturbance → zero contribution
        return lambda Ta: 0.0, lambda Ta: 0.0

    @jit
    def I_inc_r(Ta):
        T_prof = Ta + p.deltaT_r
        return jnp.trapezoid(1.0 / p.t_inc(T_prof), x=p.t)

    @jit
    def I_rx_r(Ta):
        T_prof = Ta + p.deltaT_r
        return jnp.trapezoid(p.b(T_prof), x=p.t)

    return I_inc_r, I_rx_r


# -----------------------------------------------------------
# One‑window integrals (re‑evaluated each time T_a changes)
# -----------------------------------------------------------

def _single_window_integrals(p: JMAKParams):
    """Return jit‑compiled integrators for one disturbance window."""

    if p.tau_r == 0.0 or p.N_d == 0 or p.deltaT_r is None:
        # Degenerate case – no disturbance → zero contribution
        return lambda Ta: 0.0, lambda Ta: 0.0

    @jit
    def I_inc_r(Ta):
        T_prof = Ta + p.deltaT_r
        return jnp.trapezoid(1.0 / p.t_inc(T_prof), x=p.t)

    @jit
    def I_rx_r(Ta):
        T_prof = Ta + p.deltaT_r
        return jnp.trapezoid(p.b(T_prof), x=p.t)

    return I_inc_r, I_rx_r


# -----------------------------------------------------------
# Residual vector for Broyden (F1, F2, F3) = 0
# -----------------------------------------------------------

def _make_residuals(p: JMAKParams,
                    eps_t: float = 1e-16):
    """Return bounded residuals using a sigmoidal re‑parameterisation.

    We optimise unconstrained variables z = [theta, rho, kappa] in R^3 and map
    them to the physical domain via the logistic function:

        T_a      =  T_min  + logistic(theta) * (T_max - T_min)
        tau_inc  =  logistic(rho)   * tau_op
        N_d_inc  =  logistic(kappa) * N_d

    This guarantees that every function evaluation stays inside the admissible
    box – no clipping, no penalties, no NaNs.
    """

    I_inc_r, I_rx_r = _single_window_integrals(p)
    ln_term = p.ln_term

    logistic = lambda x: 1.0 / (1.0 + jnp.exp(-x))

    @jit
    def residuals(z):
        theta, rho, kappa = z

        # ---------- inverse transform ----------
        Ta       = p.Tmin + logistic(theta) * (p.Tmax - p.Tmin)
        tau_inc  = logistic(rho)   * p.tau_op
        N_d_inc  = logistic(kappa) * p.N_d

        tau_rx   = p.tau_op - tau_inc
        N_d_rx   = p.N_d   - N_d_inc

        # avoid division by zero inside F3 (does not affect root)
        tau_rx = jnp.where(tau_rx < eps_t,  eps_t, tau_rx)
        N_d_rx = jnp.where(N_d_rx <  eps_t,  eps_t, N_d_rx)

        # ---------- residuals ----------
        F1 = (
            (tau_inc - N_d_inc * p.tau_r) / p.t_inc(Ta)
            + N_d_inc * I_inc_r(Ta)
            - 1.0
        )

        # rescale F2 to O(1): use relative error to ln_term
        num_rx = (tau_rx - N_d_rx * p.tau_r) * p.b(Ta) + N_d_rx * I_rx_r(Ta)
        F2 = num_rx / ln_term - 1.0 

                # scale F3 by (N_d + 1) * tau_op to keep magnitude ~1
        F3 = (N_d_inc * tau_rx - p.alpha * tau_inc * N_d_rx) / ( (p.N_d + 1.0) * p.tau_op )
        return jnp.array([F1, F2, F3])

    return residuals


# -----------------------------------------------------------
# Solver using jaxopt.Broyden (quasi‑Newton root finder)
# -----------------------------------------------------------

def solve_Ta_and_tau_inc(
    params: JMAKParams,
    x0: Tuple[float, float, float] = (1200.0, 0.5, 0.0),  # physical guess
    tol: float = 1e-3,
    maxiter: int = int(1e4),
    eps_t: float = 1e-16
):
    """Root‑solve using Broyden in *unconstrained* space.

    Parameters
    ----------
    params   : JMAKParams
    x0_phys  : initial guess in physical variables (T_a [K], tau_inc [s], N_d_inc)
    tol      : tolerance on ‖F‖₂
    maxiter  : maximum Broyden iterations
    """

    T0, tau_inc0, N_d_inc0 = x0

    # logit function (inverse of logistic)
    def logit(y):
        return jnp.log(y / (1.0 - y))

    # map initial guess to unconstrained variables
    theta0 = logit((T0 - params.Tmin) / (params.Tmax - params.Tmin + eps_t))
    rho0   = logit(tau_inc0 / (params.tau_op + eps_t))
    kappa0 = logit(N_d_inc0 / (params.N_d + eps_t)) if params.N_d > 0 else 0.0

    residuals = _make_residuals(params)
    solver = Broyden(fun=residuals, tol=tol, maxiter=maxiter,
                     max_stepsize = 1.,implicit_diff= False)
    sol = solver.run(jnp.array([theta0, rho0, kappa0], dtype=float))

    theta, rho, kappa = sol.params
    logistic = lambda x: 1.0 / (1.0 + jnp.exp(-x))

    Ta_opt      = params.Tmin + logistic(theta) * (params.Tmax - params.Tmin)
    tau_inc_opt = logistic(rho)   * params.tau_op
    N_d_inc_opt = logistic(kappa) * params.N_d

    tau_rx_opt  = params.tau_op - tau_inc_opt
    N_d_rx_opt  = params.N_d   - N_d_inc_opt

    info = {
        "iterations": int(sol.state.iter_num),
        "residual_norm": float(sol.state.error),
    }

    return (
        float(Ta_opt),
        float(tau_inc_opt),
        float(tau_rx_opt),
        float(N_d_inc_opt),
        float(N_d_rx_opt),
        info,
    )





# -----------------------------------------------------------
# Optional: invert isothermal equation for reference temperature
# -----------------------------------------------------------

def invert_isothermal_T(
    params: JMAKParams,
    T_low: float = 200.0,
    T_high: float = 3000.0,
    tol: float = 1e-6,
):
    """Return the isothermal temperature that gives ``X_star`` in ``tau_op`` seconds."""

    ln_term = (-jnp.log1p(-params.X_star)) ** (1.0 / params.n)

    def g(T):
        ff = params.t_inc(T) + ln_term / params.b(T) - params.tau_op
        return ff

    root_solver = Bisection(g, T_low, T_high, tol=tol)
    return float(root_solver.run().params)

# %% [markdown]
# ### Isothermal Verification

# %%
import sys
wlpath = '../recrystallization'
sys.path.append(
    wlpath
)
from external import read_jmak_model_inference,_RX_INF_PATH as rxp

jmak_model = read_jmak_model_inference(
    rxp.joinpath(f'JMAK_Lopez et al. (2015) - MR_trunc_normal_params.csv')
)
a1,B1,a2,B2,n = jmak_model.a1,jmak_model.B1,jmak_model.a2,jmak_model.B2,jmak_model.n
YEAR_TO_SECONDS = 24. * 365.*3600.
N_d = 0
tau_r = 10.
p = JMAKParams(
    n=n,
    a1=a1,
    B1=B1,
    a2=a2,
    B2=B2,
    X_star=0.1,
    tau_op=YEAR_TO_SECONDS,
    tau_r=tau_r,
    N_d = N_d,
    alpha = 1.0,
    deltaT_r=None,
    t = None,
)

T_iso = invert_isothermal_T(p)
Ta = T_iso
tau_inc = p.t_inc(Ta)
tau_rx = p.ln_term/p.b(Ta)
print('incubation time:',  p.t_inc(Ta))
print('recrystallization time:', tau_rx)
N_d_inc = 0.
I_inc_r = 0.
N_d_rx = 0.
I_rx_r = 0.

t = jnp.linspace(0, tau_r, 1000)

print("isothermal temperature:", T_iso - 273.15)
p.deltaT_r = jnp.ones(t.shape[0])*0.
p.t = t
Ta, tau_inc,tau_rx,N_d_inc,N_d_rx,error = solve_Ta_and_tau_inc(p, 
                                                    x0=(T_iso,tau_inc*2.3,0.5*N_d))

print("Solved baseline temperature (C):", Ta - 273.15)
print("Incubation time (s):", tau_inc)
print("Recrystallisation time (s):", tau_rx)
print('N_d_inc:', N_d_inc)
print('N_d_rx:', N_d_rx)
print("Error:", error)
#print("Recrystallisation time (s):", tau_rx)
#print("LBFGS info:", info)
# Out:
# incubation time: 21827.934
# recrystallization time: 31514226.0
# isothermal temperature: 1086.27724609375
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.31620657444000244 Stepsize:1.0  Objective Value:1.9999394416809082  Decrease Error:0.31620657444000244
# INFO: jaxopt.BacktrackingLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 0.31448233127593994 Stepsize:0.800000011920929  Objective Value:1.9994676113128662  Decrease Error:0.31448233127593994
# INFO: jaxopt.BacktrackingLineSearch: Iter: 3 Minimum Decrease & Curvature Errors (stop. crit.): 0.3107224702835083 Stepsize:0.64000004529953  Objective Value:1.9967097043991089  Decrease Error:0.3107224702835083
# INFO: jaxopt.BacktrackingLineSearch: Iter: 4 Minimum Decrease & Curvature Errors (stop. crit.): 0.29873478412628174 Stepsize:0.5120000243186951  Objective Value:1.9855235815048218  Decrease Error:0.29873478412628174
# INFO: jaxopt.BacktrackingLineSearch: Iter: 5 Minimum Decrease & Curvature Errors (stop. crit.): 0.26538801193237305 Stepsize:0.40960001945495605  Objective Value:1.9528180360794067  Decrease Error:0.26538801193237305
# INFO: jaxopt.BacktrackingLineSearch: Iter: 6 Minimum Decrease & Curvature Errors (stop. crit.): 0.19283688068389893 Stepsize:0.3276800215244293  Objective Value:1.8807799816131592  Decrease Error:0.19283688068389893
# INFO: jaxopt.BacktrackingLineSearch: Iter: 7 Minimum Decrease & Curvature Errors (stop. crit.): 0.06800234317779541 Stepsize:0.2621440291404724  Objective Value:1.7563557624816895  Decrease Error:0.06800234317779541
# INFO: jaxopt.BacktrackingLineSearch: Iter: 8 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:0.20971523225307465  Objective Value:1.581958293914795  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.22731906175613403 Stepsize:0.31457284092903137  Objective Value:1.381243348121643  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 0.1968356966972351 Stepsize:0.25165829062461853  Objective Value:1.4256782531738281  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 3 Minimum Decrease & Curvature Errors (stop. crit.): 0.1701180338859558 Stepsize:0.2013266384601593  Objective Value:1.459778070449829  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 4 Minimum Decrease & Curvature Errors (stop. crit.): 0.14775371551513672 Stepsize:0.16106131672859192  Objective Value:1.4860661029815674  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 5 Minimum Decrease & Curvature Errors (stop. crit.): 0.12944060564041138 Stepsize:0.128849059343338  Objective Value:1.5064417123794556  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 6 Minimum Decrease & Curvature Errors (stop. crit.): 0.11461573839187622 Stepsize:0.10307925194501877  Objective Value:1.5223143100738525  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 7 Minimum Decrease & Curvature Errors (stop. crit.): 0.1026870608329773 Stepsize:0.08246340602636337  Objective Value:1.5347357988357544  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 8 Minimum Decrease & Curvature Errors (stop. crit.): 0.09311825037002563 Stepsize:0.06597072631120682  Objective Value:1.5444965362548828  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 9 Minimum Decrease & Curvature Errors (stop. crit.): 0.0854572057723999 Stepsize:0.052776582539081573  Objective Value:1.5521910190582275  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 10 Minimum Decrease & Curvature Errors (stop. crit.): 0.07932889461517334 Stepsize:0.04222126677632332  Objective Value:1.5582735538482666  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 11 Minimum Decrease & Curvature Errors (stop. crit.): 0.07442790269851685 Stepsize:0.033777013421058655  Objective Value:1.563093900680542  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 12 Minimum Decrease & Curvature Errors (stop. crit.): 0.07051044702529907 Stepsize:0.027021611109375954  Objective Value:1.566919207572937  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 13 Minimum Decrease & Curvature Errors (stop. crit.): 0.0673779845237732 Stepsize:0.021617289632558823  Objective Value:1.5699613094329834  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 14 Minimum Decrease & Curvature Errors (stop. crit.): 0.06487441062927246 Stepsize:0.017293831333518028  Objective Value:1.5723820924758911  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 15 Minimum Decrease & Curvature Errors (stop. crit.): 0.06287229061126709 Stepsize:0.013835065066814423  Objective Value:1.5743111371994019  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.026781082153320312 Stepsize:0.020752597600221634  Objective Value:1.6010949611663818  Decrease Error:0.026781082153320312
# INFO: jaxopt.BacktrackingLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 0.021537303924560547 Stepsize:0.016602078452706337  Objective Value:1.5958505868911743  Decrease Error:0.021537303924560547
# INFO: jaxopt.BacktrackingLineSearch: Iter: 3 Minimum Decrease & Curvature Errors (stop. crit.): 0.017301082611083984 Stepsize:0.013281662948429585  Objective Value:1.591614007949829  Decrease Error:0.017301082611083984
# INFO: jaxopt.BacktrackingLineSearch: Iter: 4 Minimum Decrease & Curvature Errors (stop. crit.): 0.013887166976928711 Stepsize:0.010625330731272697  Objective Value:1.5881997346878052  Decrease Error:0.013887166976928711
# INFO: jaxopt.BacktrackingLineSearch: Iter: 5 Minimum Decrease & Curvature Errors (stop. crit.): 0.011138558387756348 Stepsize:0.008500264957547188  Objective Value:1.5854507684707642  Decrease Error:0.011138558387756348
# INFO: jaxopt.BacktrackingLineSearch: Iter: 6 Minimum Decrease & Curvature Errors (stop. crit.): 0.008929967880249023 Stepsize:0.00680021196603775  Objective Value:1.5832420587539673  Decrease Error:0.008929967880249023
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.012665152549743652 Stepsize:0.010200317949056625  Objective Value:1.595908522605896  Decrease Error:0.012665152549743652
# INFO: jaxopt.BacktrackingLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 0.01015770435333252 Stepsize:0.008160254918038845  Objective Value:1.5934008359909058  Decrease Error:0.01015770435333252
# INFO: jaxopt.BacktrackingLineSearch: Iter: 3 Minimum Decrease & Curvature Errors (stop. crit.): 0.008142471313476562 Stepsize:0.006528203841298819  Objective Value:1.5913853645324707  Decrease Error:0.008142471313476562
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.01170802116394043 Stepsize:0.009792305529117584  Objective Value:1.6030945777893066  Decrease Error:0.01170802116394043
# INFO: jaxopt.BacktrackingLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 0.009392499923706055 Stepsize:0.007833844982087612  Objective Value:1.6007788181304932  Decrease Error:0.009392499923706055
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.012681722640991211 Stepsize:0.011750767007470131  Objective Value:1.6134618520736694  Decrease Error:0.012681722640991211
# INFO: jaxopt.BacktrackingLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 0.010202407836914062 Stepsize:0.009400613605976105  Objective Value:1.6109822988510132  Decrease Error:0.010202407836914062
# INFO: jaxopt.BacktrackingLineSearch: Iter: 3 Minimum Decrease & Curvature Errors (stop. crit.): 0.008198261260986328 Stepsize:0.007520490791648626  Objective Value:1.6089779138565063  Decrease Error:0.008198261260986328
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.05858362093567848 Stepsize:0.011280735954642296  Objective Value:1.6182398796081543  Decrease Error:0.009261012077331543
# INFO: jaxopt.BacktrackingLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 0.02299630641937256 Stepsize:0.009024589322507381  Objective Value:1.6165268421173096  Decrease Error:0.007548093795776367
# INFO: jaxopt.BacktrackingLineSearch: Iter: 3 Minimum Decrease & Curvature Errors (stop. crit.): 0.006122231483459473 Stepsize:0.0072196717374026775  Objective Value:1.6151007413864136  Decrease Error:0.006122231483459473
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.4384099841117859 Stepsize:0.010829507373273373  Objective Value:1.6173924207687378  Decrease Error:0.0022912025451660156
# INFO: jaxopt.BacktrackingLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 0.3094598650932312 Stepsize:0.008663605898618698  Objective Value:1.6173800230026245  Decrease Error:0.002278923988342285
# INFO: jaxopt.BacktrackingLineSearch: Iter: 3 Minimum Decrease & Curvature Errors (stop. crit.): 0.21996039152145386 Stepsize:0.006930884905159473  Objective Value:1.617182731628418  Decrease Error:0.002081751823425293
# INFO: jaxopt.BacktrackingLineSearch: Iter: 4 Minimum Decrease & Curvature Errors (stop. crit.): 0.15613669157028198 Stepsize:0.005544708110392094  Objective Value:1.6169180870056152  Decrease Error:0.0018171072006225586
# INFO: jaxopt.BacktrackingLineSearch: Iter: 5 Minimum Decrease & Curvature Errors (stop. crit.): 0.10960215330123901 Stepsize:0.004435766488313675  Objective Value:1.6166460514068604  Decrease Error:0.0015450716018676758
# INFO: jaxopt.BacktrackingLineSearch: Iter: 6 Minimum Decrease & Curvature Errors (stop. crit.): 0.07506102323532104 Stepsize:0.0035486132837831974  Objective Value:1.6163924932479858  Decrease Error:0.0012916326522827148
# INFO: jaxopt.BacktrackingLineSearch: Iter: 7 Minimum Decrease & Curvature Errors (stop. crit.): 0.049044787883758545 Stepsize:0.002838890766724944  Objective Value:1.6161680221557617  Decrease Error:0.0010671615600585938
# INFO: jaxopt.BacktrackingLineSearch: Iter: 8 Minimum Decrease & Curvature Errors (stop. crit.): 0.0292169451713562 Stepsize:0.0022711127530783415  Objective Value:1.6159762144088745  Decrease Error:0.0008753538131713867
# INFO: jaxopt.BacktrackingLineSearch: Iter: 9 Minimum Decrease & Curvature Errors (stop. crit.): 0.01396101713180542 Stepsize:0.0018168902024626732  Objective Value:1.6158132553100586  Decrease Error:0.0007123947143554688
# INFO: jaxopt.BacktrackingLineSearch: Iter: 10 Minimum Decrease & Curvature Errors (stop. crit.): 0.002132594585418701 Stepsize:0.0014535122318193316  Objective Value:1.6156792640686035  Decrease Error:0.0005784034729003906
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.14917898178100586 Stepsize:0.0021802682895213366  Objective Value:1.6152504682540894  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 0.11942815780639648 Stepsize:0.001744214678183198  Objective Value:1.6153607368469238  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 3 Minimum Decrease & Curvature Errors (stop. crit.): 0.09657716751098633 Stepsize:0.0013953717425465584  Objective Value:1.6154392957687378  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 4 Minimum Decrease & Curvature Errors (stop. crit.): 0.07889032363891602 Stepsize:0.0011162974406033754  Objective Value:1.61549711227417  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 5 Minimum Decrease & Curvature Errors (stop. crit.): 0.06510782241821289 Stepsize:0.0008930379408411682  Objective Value:1.6155389547348022  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 6 Minimum Decrease & Curvature Errors (stop. crit.): 0.054316043853759766 Stepsize:0.0007144303526729345  Objective Value:1.6155707836151123  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 7 Minimum Decrease & Curvature Errors (stop. crit.): 0.0458226203918457 Stepsize:0.0005715442821383476  Objective Value:1.6155956983566284  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 8 Minimum Decrease & Curvature Errors (stop. crit.): 0.03912687301635742 Stepsize:0.0004572354373522103  Objective Value:1.6156138181686401  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 9 Minimum Decrease & Curvature Errors (stop. crit.): 0.033823490142822266 Stepsize:0.0003657883498817682  Objective Value:1.6156275272369385  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 10 Minimum Decrease & Curvature Errors (stop. crit.): 0.029619693756103516 Stepsize:0.00029263069154694676  Objective Value:1.6156386137008667  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 11 Minimum Decrease & Curvature Errors (stop. crit.): 0.026279926300048828 Stepsize:0.00023410456196870655  Objective Value:1.615647554397583  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 12 Minimum Decrease & Curvature Errors (stop. crit.): 0.023624897003173828 Stepsize:0.00018728365830611438  Objective Value:1.6156541109085083  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 13 Minimum Decrease & Curvature Errors (stop. crit.): 0.021506786346435547 Stepsize:0.0001498269266448915  Objective Value:1.6156591176986694  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 14 Minimum Decrease & Curvature Errors (stop. crit.): 0.019818782806396484 Stepsize:0.00011986154277110472  Objective Value:1.6156631708145142  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 15 Minimum Decrease & Curvature Errors (stop. crit.): 0.018478870391845703 Stepsize:9.588923421688378e-05  Objective Value:1.615666151046753  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.08070699125528336 Stepsize:0.00014383385132532567  Objective Value:1.615568995475769  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 0.07795757055282593 Stepsize:0.00011506707960506901  Objective Value:1.6155887842178345  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 3 Minimum Decrease & Curvature Errors (stop. crit.): 0.07576698064804077 Stepsize:9.205366222886369e-05  Objective Value:1.6156041622161865  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 4 Minimum Decrease & Curvature Errors (stop. crit.): 0.0740169882774353 Stepsize:7.364292832789943e-05  Objective Value:1.615617275238037  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 5 Minimum Decrease & Curvature Errors (stop. crit.): 0.07262557744979858 Stepsize:5.891434193472378e-05  Objective Value:1.6156266927719116  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 6 Minimum Decrease & Curvature Errors (stop. crit.): 0.07150596380233765 Stepsize:4.7131474275374785e-05  Objective Value:1.6156355142593384  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 7 Minimum Decrease & Curvature Errors (stop. crit.): 0.07061809301376343 Stepsize:3.770518014789559e-05  Objective Value:1.6156408786773682  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 8 Minimum Decrease & Curvature Errors (stop. crit.): 0.06990379095077515 Stepsize:3.0164144845912233e-05  Objective Value:1.6156463623046875  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 9 Minimum Decrease & Curvature Errors (stop. crit.): 0.06933540105819702 Stepsize:2.4131315512931906e-05  Objective Value:1.6156502962112427  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 10 Minimum Decrease & Curvature Errors (stop. crit.): 0.06888145208358765 Stepsize:1.9305052774143405e-05  Objective Value:1.6156539916992188  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 11 Minimum Decrease & Curvature Errors (stop. crit.): 0.06852096319198608 Stepsize:1.5444042219314724e-05  Objective Value:1.6156560182571411  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 12 Minimum Decrease & Curvature Errors (stop. crit.): 0.06823009252548218 Stepsize:1.2355233593552839e-05  Objective Value:1.615658164024353  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 13 Minimum Decrease & Curvature Errors (stop. crit.): 0.06799644231796265 Stepsize:9.884187420539092e-06  Objective Value:1.615659475326538  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 14 Minimum Decrease & Curvature Errors (stop. crit.): 0.06781619787216187 Stepsize:7.907349754532333e-06  Objective Value:1.6156607866287231  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 15 Minimum Decrease & Curvature Errors (stop. crit.): 0.06765979528427124 Stepsize:6.325879894575337e-06  Objective Value:1.615662693977356  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.12015822529792786 Stepsize:9.488820069236681e-06  Objective Value:1.6156511306762695  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 0.11990833282470703 Stepsize:7.591056146338815e-06  Objective Value:1.6156539916992188  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 3 Minimum Decrease & Curvature Errors (stop. crit.): 0.11971187591552734 Stepsize:6.072844826121582e-06  Objective Value:1.615654468536377  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 4 Minimum Decrease & Curvature Errors (stop. crit.): 0.11954975128173828 Stepsize:4.858276042796206e-06  Objective Value:1.6156563758850098  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 5 Minimum Decrease & Curvature Errors (stop. crit.): 0.11942577362060547 Stepsize:3.886621016135905e-06  Objective Value:1.6156578063964844  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 6 Minimum Decrease & Curvature Errors (stop. crit.): 0.11931896209716797 Stepsize:3.109296812908724e-06  Objective Value:1.6156591176986694  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 7 Minimum Decrease & Curvature Errors (stop. crit.): 0.11923885345458984 Stepsize:2.4874375412764493e-06  Objective Value:1.6156593561172485  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 8 Minimum Decrease & Curvature Errors (stop. crit.): 0.11917591094970703 Stepsize:1.9899500784958946e-06  Objective Value:1.6156600713729858  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 9 Minimum Decrease & Curvature Errors (stop. crit.): 0.1191244125366211 Stepsize:1.5919600855340832e-06  Objective Value:1.615660548210144  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 10 Minimum Decrease & Curvature Errors (stop. crit.): 0.11907672882080078 Stepsize:1.273568045689899e-06  Objective Value:1.6156612634658813  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 11 Minimum Decrease & Curvature Errors (stop. crit.): 0.1190500259399414 Stepsize:1.0188545047640218e-06  Objective Value:1.615661382675171  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 12 Minimum Decrease & Curvature Errors (stop. crit.): 0.1190195083618164 Stepsize:8.150836379172688e-07  Objective Value:1.615661859512329  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 13 Minimum Decrease & Curvature Errors (stop. crit.): 0.11899852752685547 Stepsize:6.520669444398663e-07  Objective Value:1.6156617403030396  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 14 Minimum Decrease & Curvature Errors (stop. crit.): 0.11897754669189453 Stepsize:5.216535896579444e-07  Objective Value:1.6156623363494873  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 15 Minimum Decrease & Curvature Errors (stop. crit.): 0.11896800994873047 Stepsize:4.1732286604201363e-07  Objective Value:1.615661859512329  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:1.0  Objective Value:4.663899807918533e+29  Decrease Error:4.663899807918533e+29
# INFO: jaxopt.BacktrackingLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 4.5088010476803925e+29 Stepsize:0.800000011920929  Objective Value:4.5088010476803925e+29  Decrease Error:4.5088010476803925e+29
# INFO: jaxopt.BacktrackingLineSearch: Iter: 3 Minimum Decrease & Curvature Errors (stop. crit.): 3.8465609284284644e+29 Stepsize:0.64000004529953  Objective Value:3.8465609284284644e+29  Decrease Error:3.8465609284284644e+29
# INFO: jaxopt.BacktrackingLineSearch: Iter: 4 Minimum Decrease & Curvature Errors (stop. crit.): 2.271486801353856e+29 Stepsize:0.5120000243186951  Objective Value:2.271486801353856e+29  Decrease Error:2.271486801353856e+29
# INFO: jaxopt.BacktrackingLineSearch: Iter: 5 Minimum Decrease & Curvature Errors (stop. crit.): 6.107936670905848e+28 Stepsize:0.40960001945495605  Objective Value:6.107936670905848e+28  Decrease Error:6.107936670905848e+28
# INFO: jaxopt.BacktrackingLineSearch: Iter: 6 Minimum Decrease & Curvature Errors (stop. crit.): 4.597162085161417e+27 Stepsize:0.3276800215244293  Objective Value:4.597162085161417e+27  Decrease Error:4.597162085161417e+27
# INFO: jaxopt.BacktrackingLineSearch: Iter: 7 Minimum Decrease & Curvature Errors (stop. crit.): 7.000528307926331e+25 Stepsize:0.2621440291404724  Objective Value:7.000528307926331e+25  Decrease Error:7.000528307926331e+25
# INFO: jaxopt.BacktrackingLineSearch: Iter: 8 Minimum Decrease & Curvature Errors (stop. crit.): 2.2331352755335588e+23 Stepsize:0.20971523225307465  Objective Value:2.2331352755335588e+23  Decrease Error:2.2331352755335588e+23
# INFO: jaxopt.BacktrackingLineSearch: Iter: 9 Minimum Decrease & Curvature Errors (stop. crit.): 2.2383766238896377e+20 Stepsize:0.16777218878269196  Objective Value:2.2383766238896377e+20  Decrease Error:2.2383766238896377e+20
# INFO: jaxopt.BacktrackingLineSearch: Iter: 10 Minimum Decrease & Curvature Errors (stop. crit.): 1.2919129341375283e+17 Stepsize:0.1342177540063858  Objective Value:1.2919129341375283e+17  Decrease Error:1.2919129341375283e+17
# INFO: jaxopt.BacktrackingLineSearch: Iter: 11 Minimum Decrease & Curvature Errors (stop. crit.): 77553352048640.0 Stepsize:0.10737420618534088  Objective Value:77553352048640.0  Decrease Error:77553352048640.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 12 Minimum Decrease & Curvature Errors (stop. crit.): 75145060352.0 Stepsize:0.08589936792850494  Objective Value:75145060352.0  Decrease Error:75145060352.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 13 Minimum Decrease & Curvature Errors (stop. crit.): 151409104.0 Stepsize:0.06871949881315231  Objective Value:151409104.0  Decrease Error:151409104.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 14 Minimum Decrease & Curvature Errors (stop. crit.): 698302.25 Stepsize:0.05497559905052185  Objective Value:698303.875  Decrease Error:698302.25
# INFO: jaxopt.BacktrackingLineSearch: Iter: 15 Minimum Decrease & Curvature Errors (stop. crit.): 7201.76123046875 Stepsize:0.04398047924041748  Objective Value:7203.376953125  Decrease Error:7201.76123046875
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:0.06597071886062622  Objective Value:2782.3388671875  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 957.570556640625 Stepsize:0.09895607829093933  Objective Value:3739.991943359375  Decrease Error:957.570556640625
# INFO: jaxopt.BacktrackingLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 743.16455078125 Stepsize:0.07916486263275146  Objective Value:3525.5693359375  Decrease Error:743.16455078125
# INFO: jaxopt.BacktrackingLineSearch: Iter: 3 Minimum Decrease & Curvature Errors (stop. crit.): 580.437255859375 Stepsize:0.06333189457654953  Objective Value:3362.828857421875  Decrease Error:580.437255859375
# INFO: jaxopt.BacktrackingLineSearch: Iter: 4 Minimum Decrease & Curvature Errors (stop. crit.): 455.552490234375 Stepsize:0.050665516406297684  Objective Value:3237.93359375  Decrease Error:455.552490234375
# INFO: jaxopt.BacktrackingLineSearch: Iter: 5 Minimum Decrease & Curvature Errors (stop. crit.): 358.93115234375 Stepsize:0.04053241387009621  Objective Value:3141.3037109375  Decrease Error:358.93115234375
# INFO: jaxopt.BacktrackingLineSearch: Iter: 6 Minimum Decrease & Curvature Errors (stop. crit.): 283.683837890625 Stepsize:0.032425932586193085  Objective Value:3066.0498046875  Decrease Error:283.683837890625
# INFO: jaxopt.BacktrackingLineSearch: Iter: 7 Minimum Decrease & Curvature Errors (stop. crit.): 224.76025390625 Stepsize:0.025940746068954468  Objective Value:3007.120849609375  Decrease Error:224.76025390625
# INFO: jaxopt.BacktrackingLineSearch: Iter: 8 Minimum Decrease & Curvature Errors (stop. crit.): 178.4130859375 Stepsize:0.020752597600221634  Objective Value:2960.769287109375  Decrease Error:178.4130859375
# INFO: jaxopt.BacktrackingLineSearch: Iter: 9 Minimum Decrease & Curvature Errors (stop. crit.): 141.8681640625 Stepsize:0.016602078452706337  Objective Value:2924.220947265625  Decrease Error:141.8681640625
# INFO: jaxopt.BacktrackingLineSearch: Iter: 10 Minimum Decrease & Curvature Errors (stop. crit.): 112.937255859375 Stepsize:0.013281662948429585  Objective Value:2895.287109375  Decrease Error:112.937255859375
# INFO: jaxopt.BacktrackingLineSearch: Iter: 11 Minimum Decrease & Curvature Errors (stop. crit.): 89.973876953125 Stepsize:0.010625330731272697  Objective Value:2872.321533203125  Decrease Error:89.973876953125
# INFO: jaxopt.BacktrackingLineSearch: Iter: 12 Minimum Decrease & Curvature Errors (stop. crit.): 71.777587890625 Stepsize:0.008500264957547188  Objective Value:2854.12353515625  Decrease Error:71.777587890625
# INFO: jaxopt.BacktrackingLineSearch: Iter: 13 Minimum Decrease & Curvature Errors (stop. crit.): 57.268310546875 Stepsize:0.00680021196603775  Objective Value:2839.61279296875  Decrease Error:57.268310546875
# INFO: jaxopt.BacktrackingLineSearch: Iter: 14 Minimum Decrease & Curvature Errors (stop. crit.): 45.730712890625 Stepsize:0.005440169479697943  Objective Value:2828.07421875  Decrease Error:45.730712890625
# INFO: jaxopt.BacktrackingLineSearch: Iter: 15 Minimum Decrease & Curvature Errors (stop. crit.): 36.516357421875 Stepsize:0.004352135583758354  Objective Value:2818.85888671875  Decrease Error:36.516357421875
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 62.3544921875 Stepsize:0.006528203375637531  Objective Value:2881.219482421875  Decrease Error:62.3544921875
# INFO: jaxopt.BacktrackingLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 49.757568359375 Stepsize:0.005222562700510025  Objective Value:2868.621337890625  Decrease Error:49.757568359375
# INFO: jaxopt.BacktrackingLineSearch: Iter: 3 Minimum Decrease & Curvature Errors (stop. crit.): 39.74609375 Stepsize:0.004178050439804792  Objective Value:2858.60888671875  Decrease Error:39.74609375
# INFO: jaxopt.BacktrackingLineSearch: Iter: 4 Minimum Decrease & Curvature Errors (stop. crit.): 31.76123046875 Stepsize:0.003342440351843834  Objective Value:2850.623291015625  Decrease Error:31.76123046875
# INFO: jaxopt.BacktrackingLineSearch: Iter: 5 Minimum Decrease & Curvature Errors (stop. crit.): 25.39013671875 Stepsize:0.0026739523746073246  Objective Value:2844.25146484375  Decrease Error:25.39013671875
# INFO: jaxopt.BacktrackingLineSearch: Iter: 6 Minimum Decrease & Curvature Errors (stop. crit.): 20.267822265625 Stepsize:0.002139162039384246  Objective Value:2839.128662109375  Decrease Error:20.267822265625
# INFO: jaxopt.BacktrackingLineSearch: Iter: 7 Minimum Decrease & Curvature Errors (stop. crit.): 16.2333984375 Stepsize:0.0017113296780735254  Objective Value:2835.093994140625  Decrease Error:16.2333984375
# INFO: jaxopt.BacktrackingLineSearch: Iter: 8 Minimum Decrease & Curvature Errors (stop. crit.): 12.953125 Stepsize:0.0013690637424588203  Objective Value:2831.813232421875  Decrease Error:12.953125
# INFO: jaxopt.BacktrackingLineSearch: Iter: 9 Minimum Decrease & Curvature Errors (stop. crit.): 10.379150390625 Stepsize:0.0010952510638162494  Objective Value:2829.239013671875  Decrease Error:10.379150390625
# INFO: jaxopt.BacktrackingLineSearch: Iter: 10 Minimum Decrease & Curvature Errors (stop. crit.): 8.31396484375 Stepsize:0.0008762008510529995  Objective Value:2827.173583984375  Decrease Error:8.31396484375
# INFO: jaxopt.BacktrackingLineSearch: Iter: 11 Minimum Decrease & Curvature Errors (stop. crit.): 6.644287109375 Stepsize:0.0007009606924839318  Objective Value:2825.50390625  Decrease Error:6.644287109375
# INFO: jaxopt.BacktrackingLineSearch: Iter: 12 Minimum Decrease & Curvature Errors (stop. crit.): 5.3271484375 Stepsize:0.000560768588911742  Objective Value:2824.1865234375  Decrease Error:5.3271484375
# INFO: jaxopt.BacktrackingLineSearch: Iter: 13 Minimum Decrease & Curvature Errors (stop. crit.): 4.230224609375 Stepsize:0.00044861488277092576  Objective Value:2823.089599609375  Decrease Error:4.230224609375
# INFO: jaxopt.BacktrackingLineSearch: Iter: 14 Minimum Decrease & Curvature Errors (stop. crit.): 3.397216796875 Stepsize:0.0003588919062167406  Objective Value:2822.25634765625  Decrease Error:3.397216796875
# INFO: jaxopt.BacktrackingLineSearch: Iter: 15 Minimum Decrease & Curvature Errors (stop. crit.): 2.71728515625 Stepsize:0.00028711353661492467  Objective Value:2821.576416015625  Decrease Error:2.71728515625
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 3.378173828125 Stepsize:0.000430670304922387  Objective Value:2824.954833984375  Decrease Error:3.378173828125
# INFO: jaxopt.BacktrackingLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 2.697998046875 Stepsize:0.0003445362381171435  Objective Value:2824.274658203125  Decrease Error:2.697998046875
# INFO: jaxopt.BacktrackingLineSearch: Iter: 3 Minimum Decrease & Curvature Errors (stop. crit.): 2.17138671875 Stepsize:0.0002756289904937148  Objective Value:2823.748046875  Decrease Error:2.17138671875
# INFO: jaxopt.BacktrackingLineSearch: Iter: 4 Minimum Decrease & Curvature Errors (stop. crit.): 1.7109375 Stepsize:0.00022050319239497185  Objective Value:2823.28759765625  Decrease Error:1.7109375
# INFO: jaxopt.BacktrackingLineSearch: Iter: 5 Minimum Decrease & Curvature Errors (stop. crit.): 1.4033203125 Stepsize:0.00017640255100559443  Objective Value:2822.97998046875  Decrease Error:1.4033203125
# INFO: jaxopt.BacktrackingLineSearch: Iter: 6 Minimum Decrease & Curvature Errors (stop. crit.): 1.09619140625 Stepsize:0.0001411220437148586  Objective Value:2822.672607421875  Decrease Error:1.09619140625
# INFO: jaxopt.BacktrackingLineSearch: Iter: 7 Minimum Decrease & Curvature Errors (stop. crit.): 0.87744140625 Stepsize:0.0001128976364270784  Objective Value:2822.453857421875  Decrease Error:0.87744140625
# INFO: jaxopt.BacktrackingLineSearch: Iter: 8 Minimum Decrease & Curvature Errors (stop. crit.): 0.723876953125 Stepsize:9.031811350723729e-05  Objective Value:2822.30029296875  Decrease Error:0.723876953125
# INFO: jaxopt.BacktrackingLineSearch: Iter: 9 Minimum Decrease & Curvature Errors (stop. crit.): 0.5703125 Stepsize:7.225449371617287e-05  Objective Value:2822.146728515625  Decrease Error:0.5703125
# INFO: jaxopt.BacktrackingLineSearch: Iter: 10 Minimum Decrease & Curvature Errors (stop. crit.): 0.4384765625 Stepsize:5.780359424534254e-05  Objective Value:2822.014892578125  Decrease Error:0.4384765625
# INFO: jaxopt.BacktrackingLineSearch: Iter: 11 Minimum Decrease & Curvature Errors (stop. crit.): 0.35107421875 Stepsize:4.624287612386979e-05  Objective Value:2821.927490234375  Decrease Error:0.35107421875
# INFO: jaxopt.BacktrackingLineSearch: Iter: 12 Minimum Decrease & Curvature Errors (stop. crit.): 0.284912109375 Stepsize:3.699430089909583e-05  Objective Value:2821.861328125  Decrease Error:0.284912109375
# INFO: jaxopt.BacktrackingLineSearch: Iter: 13 Minimum Decrease & Curvature Errors (stop. crit.): 0.2412109375 Stepsize:2.9595441446872428e-05  Objective Value:2821.817626953125  Decrease Error:0.2412109375
# INFO: jaxopt.BacktrackingLineSearch: Iter: 14 Minimum Decrease & Curvature Errors (stop. crit.): 0.175537109375 Stepsize:2.3676353521295823e-05  Objective Value:2821.751953125  Decrease Error:0.175537109375
# INFO: jaxopt.BacktrackingLineSearch: Iter: 15 Minimum Decrease & Curvature Errors (stop. crit.): 0.1533203125 Stepsize:1.89410839084303e-05  Objective Value:2821.729736328125  Decrease Error:0.1533203125
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.26318359375 Stepsize:2.841162495315075e-05  Objective Value:2821.992919921875  Decrease Error:0.26318359375
# INFO: jaxopt.BacktrackingLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 0.218994140625 Stepsize:2.272930032631848e-05  Objective Value:2821.94873046875  Decrease Error:0.218994140625
# INFO: jaxopt.BacktrackingLineSearch: Iter: 3 Minimum Decrease & Curvature Errors (stop. crit.): 0.17578125 Stepsize:1.8183440261054784e-05  Objective Value:2821.905517578125  Decrease Error:0.17578125
# INFO: jaxopt.BacktrackingLineSearch: Iter: 4 Minimum Decrease & Curvature Errors (stop. crit.): 0.131591796875 Stepsize:1.4546752026944887e-05  Objective Value:2821.861328125  Decrease Error:0.131591796875
# INFO: jaxopt.BacktrackingLineSearch: Iter: 5 Minimum Decrease & Curvature Errors (stop. crit.): 0.110107421875 Stepsize:1.163740216725273e-05  Objective Value:2821.83984375  Decrease Error:0.110107421875
# INFO: jaxopt.BacktrackingLineSearch: Iter: 6 Minimum Decrease & Curvature Errors (stop. crit.): 0.087890625 Stepsize:9.309921551903244e-06  Objective Value:2821.817626953125  Decrease Error:0.087890625
# INFO: jaxopt.BacktrackingLineSearch: Iter: 7 Minimum Decrease & Curvature Errors (stop. crit.): 0.0439453125 Stepsize:7.447937150573125e-06  Objective Value:2821.773681640625  Decrease Error:0.0439453125
# INFO: jaxopt.BacktrackingLineSearch: Iter: 8 Minimum Decrease & Curvature Errors (stop. crit.): 0.0439453125 Stepsize:5.9583499023574404e-06  Objective Value:2821.773681640625  Decrease Error:0.0439453125
# INFO: jaxopt.BacktrackingLineSearch: Iter: 9 Minimum Decrease & Curvature Errors (stop. crit.): 0.022216796875 Stepsize:4.766679921885952e-06  Objective Value:2821.751953125  Decrease Error:0.022216796875
# INFO: jaxopt.BacktrackingLineSearch: Iter: 10 Minimum Decrease & Curvature Errors (stop. crit.): 0.022216796875 Stepsize:3.813343937508762e-06  Objective Value:2821.751953125  Decrease Error:0.022216796875
# INFO: jaxopt.BacktrackingLineSearch: Iter: 11 Minimum Decrease & Curvature Errors (stop. crit.): 0.022216796875 Stepsize:3.0506751045322744e-06  Objective Value:2821.751953125  Decrease Error:0.022216796875
# INFO: jaxopt.BacktrackingLineSearch: Iter: 12 Minimum Decrease & Curvature Errors (stop. crit.): 0.022216796875 Stepsize:2.4405401291005546e-06  Objective Value:2821.751953125  Decrease Error:0.022216796875
# INFO: jaxopt.BacktrackingLineSearch: Iter: 13 Minimum Decrease & Curvature Errors (stop. crit.): 0.022216796875 Stepsize:1.9524320578057086e-06  Objective Value:2821.751953125  Decrease Error:0.022216796875
# INFO: jaxopt.BacktrackingLineSearch: Iter: 14 Minimum Decrease & Curvature Errors (stop. crit.): 0.022216796875 Stepsize:1.5619456235071993e-06  Objective Value:2821.751953125  Decrease Error:0.022216796875
# INFO: jaxopt.BacktrackingLineSearch: Iter: 15 Minimum Decrease & Curvature Errors (stop. crit.): 0.022216796875 Stepsize:1.249556476068392e-06  Objective Value:2821.751953125  Decrease Error:0.022216796875
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.874334657259169e-06  Objective Value:2821.751953125  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 11231.96875 Stepsize:2.811501872201916e-06  Objective Value:2821.40087890625  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 11236.234375 Stepsize:2.2492015432362678e-06  Objective Value:2821.5107421875  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 3 Minimum Decrease & Curvature Errors (stop. crit.): 11237.984375 Stepsize:1.7993612573263817e-06  Objective Value:2821.554443359375  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 4 Minimum Decrease & Curvature Errors (stop. crit.): 11239.671875 Stepsize:1.4394889831237379e-06  Objective Value:2821.598388671875  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 5 Minimum Decrease & Curvature Errors (stop. crit.): 11241.3984375 Stepsize:1.1515911637616227e-06  Objective Value:2821.642578125  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 6 Minimum Decrease & Curvature Errors (stop. crit.): 11241.4140625 Stepsize:9.21272942377982e-07  Objective Value:2821.642578125  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 7 Minimum Decrease & Curvature Errors (stop. crit.): 11242.2734375 Stepsize:7.370183539023856e-07  Objective Value:2821.6640625  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 8 Minimum Decrease & Curvature Errors (stop. crit.): 11243.1171875 Stepsize:5.896146717532247e-07  Objective Value:2821.685791015625  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 9 Minimum Decrease & Curvature Errors (stop. crit.): 11243.1171875 Stepsize:4.716917487712635e-07  Objective Value:2821.685791015625  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 10 Minimum Decrease & Curvature Errors (stop. crit.): 11243.9609375 Stepsize:3.773534160700365e-07  Objective Value:2821.708251953125  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 11 Minimum Decrease & Curvature Errors (stop. crit.): 11244.828125 Stepsize:3.0188274990905484e-07  Objective Value:2821.729736328125  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 12 Minimum Decrease & Curvature Errors (stop. crit.): 11244.828125 Stepsize:2.4150619992724387e-07  Objective Value:2821.729736328125  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 13 Minimum Decrease & Curvature Errors (stop. crit.): 11244.828125 Stepsize:1.9320496846830792e-07  Objective Value:2821.729736328125  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 14 Minimum Decrease & Curvature Errors (stop. crit.): 11245.6875 Stepsize:1.5456397761681728e-07  Objective Value:2821.751953125  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 15 Minimum Decrease & Curvature Errors (stop. crit.): 11245.6875 Stepsize:1.2365119061996666e-07  Objective Value:2821.751953125  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Objective Value:1.8452130556106567  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:1.0  Objective Value:4.6877658925443186e+29  Decrease Error:4.6877658925443186e+29
# INFO: jaxopt.BacktrackingLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:0.800000011920929  Objective Value:4.6877658925443186e+29  Decrease Error:4.6877658925443186e+29
# INFO: jaxopt.BacktrackingLineSearch: Iter: 3 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:0.64000004529953  Objective Value:4.6877658925443186e+29  Decrease Error:4.6877658925443186e+29
# INFO: jaxopt.BacktrackingLineSearch: Iter: 4 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:0.5120000243186951  Objective Value:4.6877658925443186e+29  Decrease Error:4.6877658925443186e+29
# INFO: jaxopt.BacktrackingLineSearch: Iter: 5 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:0.40960001945495605  Objective Value:4.6877658925443186e+29  Decrease Error:4.6877658925443186e+29
# INFO: jaxopt.BacktrackingLineSearch: Iter: 6 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:0.3276800215244293  Objective Value:4.6875335521133615e+29  Decrease Error:4.6875335521133615e+29
# INFO: jaxopt.BacktrackingLineSearch: Iter: 7 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:0.2621440291404724  Objective Value:4.6827269386124374e+29  Decrease Error:4.6827269386124374e+29
# INFO: jaxopt.BacktrackingLineSearch: Iter: 8 Minimum Decrease & Curvature Errors (stop. crit.): 4.6299546820610284e+29 Stepsize:0.20971523225307465  Objective Value:4.6299546820610284e+29  Decrease Error:4.6299546820610284e+29
# INFO: jaxopt.BacktrackingLineSearch: Iter: 9 Minimum Decrease & Curvature Errors (stop. crit.): 4.2941283119982365e+29 Stepsize:0.16777218878269196  Objective Value:4.2941283119982365e+29  Decrease Error:4.2941283119982365e+29
# INFO: jaxopt.BacktrackingLineSearch: Iter: 10 Minimum Decrease & Curvature Errors (stop. crit.): 3.0841433600288293e+29 Stepsize:0.1342177540063858  Objective Value:3.0841433600288293e+29  Decrease Error:3.0841433600288293e+29
# INFO: jaxopt.BacktrackingLineSearch: Iter: 11 Minimum Decrease & Curvature Errors (stop. crit.): 1.0926397172625463e+29 Stepsize:0.10737420618534088  Objective Value:1.0926397172625463e+29  Decrease Error:1.0926397172625463e+29
# INFO: jaxopt.BacktrackingLineSearch: Iter: 12 Minimum Decrease & Curvature Errors (stop. crit.): 9.345085720288448e+27 Stepsize:0.08589936792850494  Objective Value:9.345085720288448e+27  Decrease Error:9.345085720288448e+27
# INFO: jaxopt.BacktrackingLineSearch: Iter: 13 Minimum Decrease & Curvature Errors (stop. crit.): 9.365670220639371e+25 Stepsize:0.06871949881315231  Objective Value:9.365670220639371e+25  Decrease Error:9.365670220639371e+25
# INFO: jaxopt.BacktrackingLineSearch: Iter: 14 Minimum Decrease & Curvature Errors (stop. crit.): 8.094051195735201e+22 Stepsize:0.05497559905052185  Objective Value:8.094051195735201e+22  Decrease Error:8.094051195735201e+22
# INFO: jaxopt.BacktrackingLineSearch: Iter: 15 Minimum Decrease & Curvature Errors (stop. crit.): 8.702036949277344e+18 Stepsize:0.04398047924041748  Objective Value:8.702036949277344e+18  Decrease Error:8.702036949277344e+18
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 8.852118637201326e+17 Stepsize:0.06597071886062622  Objective Value:9.587333475392815e+18  Decrease Error:8.852118637201326e+17
# INFO: jaxopt.BacktrackingLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 7.01478522916438e+17 Stepsize:0.05277657508850098  Objective Value:9.40358309215889e+18  Decrease Error:7.01478522916438e+17
# INFO: jaxopt.BacktrackingLineSearch: Iter: 3 Minimum Decrease & Curvature Errors (stop. crit.): 5.569394731080745e+17 Stepsize:0.04222125932574272  Objective Value:9.25903029845518e+18  Decrease Error:5.569394731080745e+17
# INFO: jaxopt.BacktrackingLineSearch: Iter: 4 Minimum Decrease & Curvature Errors (stop. crit.): 4.42833255889109e+17 Stepsize:0.033777009695768356  Objective Value:9.14491363587575e+18  Decrease Error:4.42833255889109e+17
# INFO: jaxopt.BacktrackingLineSearch: Iter: 5 Minimum Decrease & Curvature Errors (stop. crit.): 3.52589739527766e+17 Stepsize:0.027021607384085655  Objective Value:9.054661323421385e+18  Decrease Error:3.52589739527766e+17
# INFO: jaxopt.BacktrackingLineSearch: Iter: 6 Minimum Decrease & Curvature Errors (stop. crit.): 2.810351720595456e+17 Stepsize:0.021617285907268524  Objective Value:8.983099609127584e+18  Decrease Error:2.810351720595456e+17
# INFO: jaxopt.BacktrackingLineSearch: Iter: 7 Minimum Decrease & Curvature Errors (stop. crit.): 2.2406397706633216e+17 Stepsize:0.01729382947087288  Objective Value:8.926122916576231e+18  Decrease Error:2.2406397706633216e+17
# INFO: jaxopt.BacktrackingLineSearch: Iter: 8 Minimum Decrease & Curvature Errors (stop. crit.): 1.787937848159109e+17 Stepsize:0.013835064135491848  Objective Value:8.880848326279299e+18  Decrease Error:1.787937848159109e+17
# INFO: jaxopt.BacktrackingLineSearch: Iter: 9 Minimum Decrease & Curvature Errors (stop. crit.): 1.4275674145973862e+17 Stepsize:0.011068051680922508  Objective Value:8.844807984388243e+18  Decrease Error:1.4275674145973862e+17
# INFO: jaxopt.BacktrackingLineSearch: Iter: 10 Minimum Decrease & Curvature Errors (stop. crit.): 1.1402650262595174e+17 Stepsize:0.008854441344738007  Objective Value:8.816074996775387e+18  Decrease Error:1.1402650262595174e+17
# INFO: jaxopt.BacktrackingLineSearch: Iter: 11 Minimum Decrease & Curvature Errors (stop. crit.): 9.108849104728883e+16 Stepsize:0.007083553355187178  Objective Value:8.793134236417655e+18  Decrease Error:9.108849104728883e+16
# INFO: jaxopt.BacktrackingLineSearch: Iter: 12 Minimum Decrease & Curvature Errors (stop. crit.): 7.282780193318502e+16 Stepsize:0.005666842684149742  Objective Value:8.774871898036109e+18  Decrease Error:7.282780193318502e+16
# INFO: jaxopt.BacktrackingLineSearch: Iter: 13 Minimum Decrease & Curvature Errors (stop. crit.): 5.821254362097254e+16 Stepsize:0.004533474333584309  Objective Value:8.760255540212269e+18  Decrease Error:5.821254362097254e+16
# INFO: jaxopt.BacktrackingLineSearch: Iter: 14 Minimum Decrease & Curvature Errors (stop. crit.): 4.652858330841088e+16 Stepsize:0.003626779420301318  Objective Value:8.748569930632266e+18  Decrease Error:4.652858330841088e+16
# INFO: jaxopt.BacktrackingLineSearch: Iter: 15 Minimum Decrease & Curvature Errors (stop. crit.): 3.722121737928704e+16 Stepsize:0.002901423489674926  Objective Value:8.739262014947328e+18  Decrease Error:3.722121737928704e+16
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:0.004352135118097067  Objective Value:1.9999998807907104  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 6.81522199785789e-12 Stepsize:0.006528202444314957  Objective Value:1.9999998807907104  Decrease Error:0.0
# INFO: jaxopt.BacktrackingLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:0.009792303666472435  Objective Value:nan  Decrease Error:inf
# INFO: jaxopt.BacktrackingLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:0.007833843119442463  Objective Value:nan  Decrease Error:inf
# INFO: jaxopt.BacktrackingLineSearch: Iter: 3 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:0.00626707449555397  Objective Value:nan  Decrease Error:inf
# INFO: jaxopt.BacktrackingLineSearch: Iter: 4 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:0.005013659596443176  Objective Value:nan  Decrease Error:inf
# INFO: jaxopt.BacktrackingLineSearch: Iter: 5 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:0.004010927863419056  Objective Value:nan  Decrease Error:inf
# INFO: jaxopt.BacktrackingLineSearch: Iter: 6 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:0.003208742244169116  Objective Value:nan  Decrease Error:inf
# INFO: jaxopt.BacktrackingLineSearch: Iter: 7 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:0.002566993935033679  Objective Value:nan  Decrease Error:inf
# INFO: jaxopt.BacktrackingLineSearch: Iter: 8 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:0.002053595148026943  Objective Value:nan  Decrease Error:inf
# INFO: jaxopt.BacktrackingLineSearch: Iter: 9 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:0.0016428761882707477  Objective Value:nan  Decrease Error:inf
# INFO: jaxopt.BacktrackingLineSearch: Iter: 10 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:0.0013143009273335338  Objective Value:nan  Decrease Error:inf
# INFO: jaxopt.BacktrackingLineSearch: Iter: 11 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:0.0010514407185837626  Objective Value:nan  Decrease Error:inf
# INFO: jaxopt.BacktrackingLineSearch: Iter: 12 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:0.0008411525632254779  Objective Value:nan  Decrease Error:inf
# INFO: jaxopt.BacktrackingLineSearch: Iter: 13 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:0.0006729220622219145  Objective Value:nan  Decrease Error:inf
# INFO: jaxopt.BacktrackingLineSearch: Iter: 14 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:0.0005383376847021282  Objective Value:nan  Decrease Error:inf
# INFO: jaxopt.BacktrackingLineSearch: Iter: 15 Minimum Decrease & Curvature Errors (stop. crit.): inf Stepsize:0.0004306701594032347  Objective Value:nan  Decrease Error:inf
# Solved baseline temperature (C): nan
# Incubation time (s): nan
# Recrystallisation time (s): nan
# N_d_inc: nan
# N_d_rx: nan
# Error: {'iterations': 25, 'residual_norm': nan}
