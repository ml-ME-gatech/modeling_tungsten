# %% [markdown]
# ## Outline of Notebook
#
# The purpose of this notebook is to obtain estimates for the parameters involved in the _Arrhenius Process_ equations in both the JMAK and GL models. That is, the functions of the form:
#
# $z(T) = A \exp{\left(B/T \right)}$
#
# Or slightly more generally:
#
#
# $z(T) = A \exp{\left(\left( B/T \right)^\beta \right)}$
#
# Where $z$ is some function of temperature $T$ included in the JMAK/GL models, modeling the functional dependence of temperature. The parameters $A$ is the pre-exponential factor and $B$ is interpreted as an aggregate rate. The addition of $T^{\alpha}$ is a useful augmentation that explicitly incorporates a temperature dependence of the pre-exponential factor.  It is useful to have some estimates of what these parameters should be, so that we may inform the nonlinear regression and statistical inference required for the full recrystillization models.
#
# ### Estimation
# In the available data, we don't have direct observations of these variables, they are _latent_. Therefore, _statistical_ inference is only meaningful for the full models. However, we can still come up with estimates based on the inferred roles of these parameters. In this case, a least squares estimate from simple linear regression is sufficient, and straightforward by noting that:
#
#
# $\ln{z} = \ln{A} + \frac{B}{T}$
#
# $y = a  + B x \qquad y = \ln{z} \ , a = \ln{A} \ , x = \frac{1}{T} $
#
# And in the slightly generalized case:
#
# $\ln{z} = \ln{A}  + \left(\frac{B}{T}\right)^\beta$
#
# $y = a + bx^\beta  \qquad y = \ln{z} \ , a = \ln{A} \ , b = B^\beta \ , x = \frac{1}{T} $
#
# Which is unfortunately nonlinear. We'll fit both models.

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from matplotlib import rc
from typing import List, Tuple
import warnings
import sys
from pathlib import WindowsPath, PosixPath

PathPath = WindowsPath if 'win' in sys.platform.lower() else PosixPath
PARENT_DIR = PathPath('../')
DATA_DIR = PARENT_DIR.joinpath('rf_data')
MODEL_PATH = PARENT_DIR.joinpath('.model')

sys.path.append(str(PARENT_DIR))

from common_util import LogLinearArrhenius,FudgeFactorArrhenius, ArrheniusProcess

rc('font',**{'family':'serif','serif':['Times New Roman'],'weight': 'bold'})
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
rc('text', usetex=True)
plt.rcParams['text.latex.preamble'] = "".join([r"\usepackage{newtxtext,newtxmath}",r"\boldmath"])

#functions for estimating the incubation/starting time

def get_first_index(t: np.ndarray,
                    thresh: float):
    
    """ 
    find the first index (in a time ordered series) where the 
    value is greater than a threshold
    """
    for i in range (t.shape[0]):
        if t[i] >= thresh:
            return i
    return -1

def get_last_index(t: np.ndarray,
                   thresh: float):
    
    """"
    find the last index (in a time ordered series) where the
    value is less than a threshold
    """
    for i in range (t.shape[0] - 1,-1,-1):
        if t[i] <= thresh:
            return i
    return -1
        
def _estimate_tinc_first(data: pd.DataFrame,
                        thresh: float) -> float:

    """
    estimate the incubation/starting time using the first index approach
    """
    i = get_first_index(data['X'].to_numpy(),thresh)
    if i == -1:
        return data['time'].min()
    else:
        i = i+1 if i ==0 else i
        m = (data['time'].iloc[i] - data['time'].iloc[i - 1])/(data['X'].iloc[i] - data['X'].iloc[i - 1])
        return thresh*m + data['time'].iloc[i - 1]
        
def _estimate_tinc_last(data: pd.DataFrame,
                        thresh: float) -> float:

    """
    estimate the incubation/starting time using the last index approach
    """
    i = get_last_index(data['X'].to_numpy(),thresh)
    if i == -1:
        return data['time'].min()
    else:
        i = i-1 if i == data.shape[0] else i
        m = (data['time'].iloc[i+1] - data['time'].iloc[i])/(data['X'].iloc[i+1] - data['X'].iloc[i])
        return thresh*m + data['time'].iloc[i]

def estimate_tinc(df: pd.DataFrame,
                  thresh: float = 0.02,
                  method = 'first') -> float:
    
    """
    estimate the incubation/starting time for a given experiment at fixed temperature
    """
    data = df.copy()
    
    data.loc[:,'X'] -= data['X'].min()
    if data['time'].min() <= 0:
        pad = data.loc[data['time'] > 0,'time'].min()/2
        data.loc[:,'time'] -= data['time'].min()
        data.loc[:,'time'] += pad
    
    with warnings.catch_warnings(action ='ignore'): 
        data.sort_values('time',inplace = True)

    if method == 'first':
        return _estimate_tinc_first(data,thresh)
    elif method == 'last':
        return _estimate_tinc_last(data,thresh)
    else:
        raise ValueError('method must be either first or last')

# %% [markdown]
# ### Estimating the Incubation ($t_{inc}$) and starting ($M$) time.
#
# These parameters have the same interpretation in the JMAK and GL models respectively. That is, the process does not start until this time. A natural way to estimate this starting time would be to set some _threshold_ $X_0$ such that when $X > X_0$ then $t > t_{inc}$. The below plot demonstrates the recystillization process, there is clearly some "incubation" or "starting time". The uncertainty in the data somewhat complicates this process, but we can at least define an approximate interval for $t_{inc}$ as follows:
#
# 1. Define $\min{t_{inc}} = t_i$ as the _first point_ in the time series such that $X_{i} \geq X_0$
# 2. Define $\max{t_{inc}} = t_i$ as the _last point_ in the time series such that $X_{i} \leq X_0$
#
# Fortunately, the data is pretty smooth, so there isn't a difference between these two estimation points really. The choice of threshold however, can effect the estimate (demonstrated in the below plots). The code to perform these estimations is in the functions defined in the cell above.

# %%
import pandas as pd
from common_util import setup_axis_default
import matplotlib.pyplot as plt

data = pd.read_csv(DATA_DIR.joinpath('alfonso_data/highly_rolled.csv'),index_col = 0)
fig,axes = plt.subplots(figsize = (9,3.25),ncols = 2)

for ax,T in zip(axes,[1100,1250]):
    df = data.loc[data['temperature'] == T]
    setup_axis_default(ax)
    ax.set_xlabel(r'$t[h]$',fontsize = 12)

    ax.set_title(rf'$T = {T} \  ^\circ C$',fontsize = 12)   
    ax.errorbar(df['time'],df['X'].to_numpy(),yerr = df['std'],fmt = 'none',ecolor = 'k',capsize = 2)
    ax.scatter(df['time'],df['X'],facecolor  = plt.get_cmap('Dark2')(0.2),edgecolor = 'k',
            lw = 1.0,s = 40,marker = 'h',zorder = 1000)
    
    ftinc = estimate_tinc(df,thresh = 0.005,method = 'first')
    ltinc = estimate_tinc(df,thresh = 0.02,method = 'last')
    
    print('t_inc: [{:.4f},{:.4f}]'.format(ftinc,ltinc))
    ax.axvline(ltinc,ls = '--',color = 'k',lw = 1.0,label = 'last estimate')
    ax.axvline(ftinc,ls = '--',color = 'red',lw = 1.0,label = 'first estimate')


axes[0].legend(fontsize = 11)
axes[0].set_ylabel(r'$X$',fontsize = 12)
fig.tight_layout(pad = 0.1)
# Out:
# t_inc: [75.7362,83.1057]
# t_inc: [2.8793,3.2353]

# %%
from typing import Callable, Any

def get_tinc_estimates(df: pd.DataFrame,
                       thresh: float = 0.02,
                       method = 'first',
                       _exponent = 1.) -> pd.DataFrame:
    """
    for each temperature, estimate the incubation/starting time
    """
    temperatures = df['temperature'].unique()
    tinc = []
    for T in temperatures:
        tinc.append(estimate_tinc(df.loc[df['temperature'] == T],thresh,method = method)) 
        
    return pd.DataFrame(np.array([temperatures**_exponent,tinc]).T,columns = ['temperature','tinc'])

def estimate_arrhenius(T: np.ndarray,
                        z: np.ndarray,
                        est_order = 2) -> Tuple[ArrheniusProcess,Callable]:
    
    if est_order == 2:
        return LogLinearArrhenius().fit(T,z)
    else:
        return FudgeFactorArrhenius().fit(T,z,1.0,beta_bounds = (0.1,3.0))
                                
def estimate_incubation_time_function(data_set: List[pd.DataFrame],
                                      thresh: float = 0.02,
                                      method= 'first',
                                      est_order = 2,
                                      _exponent = 1.) -> Tuple[ArrheniusProcess,pd.DataFrame]:

    """ 
    from a list of dataframes, aggregate the data and estimate the incubation time
    """
    
    tinc = []
    for data in data_set:
        tinc.append(
            get_tinc_estimates(data,thresh = thresh,method = method,_exponent = _exponent)
        )
    
    tinc = pd.concat(tinc)
    res = estimate_arrhenius(tinc['temperature'].to_numpy(),
                                      tinc['tinc'].to_numpy(),est_order)
    
    return res,tinc

def estimate_b(df: pd.DataFrame,
                   n: float,
                   eps: float = 1e-3,
                   **kwargs):
    """ 
    estimate the parameter "b" in the Arrhenius equation
    invovlved in the JMAK model from data for a specific temperature
    """
    tinc = estimate_tinc(df,**kwargs)
    df.loc[:,'time'] -= tinc
    df = df.loc[df['time'] >= 0]
    df = df.loc[df['X'] <= 1 - eps,:]
    df.loc[df['X'].to_numpy() <=  0,:] = eps

    y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
    return 1./np.exp(y)

def get_b_estimate(df: pd.DataFrame,
                   n: float,
                   eps: float = 1e-3,
                   _exponent = 1.,
                   **kwargs):
    """ 
    estimate the parameter "b" in the Arrhenius equation
    involved in the JMAK model
    """
    temperatures = df['temperature'].unique()
    b = []
    temps = []
    for T in temperatures:
        b.append(
            estimate_b(df.loc[df['temperature'] == T],n,eps = eps,**kwargs)
            ) 
        temps.append(np.array([T]*b[-1].shape[0]))
        
    
    return pd.DataFrame(
        np.array([np.concatenate(temps)**_exponent,np.concatenate(b)]).T,
        columns = ['temperature','b'])

def estimate_b_function(data_set: List[pd.DataFrame],
                        n: float,
                        eps: float = 1e-3,
                        est_order = 1,
                        **kwargs) -> Tuple[ArrheniusProcess,pd.DataFrame]:
    """ 
    fit the Arrhenius equation to the data
    """
    b = []
    for data in data_set:
        b.append(
            get_b_estimate(data.copy(),n,eps = eps,**kwargs)
        )
    
    b = pd.concat(b)
    res = estimate_arrhenius(b['temperature'].to_numpy(),
                             b['b'].to_numpy(),est_order)
    
    return res,b

def estimate_gl_rate(df: pd.DataFrame,
                     nu: float,
                     eps: float = 1e-3,
                     thresh: float = 0.02,
                     method: str = 'first'):
    
    """ 
    estimate the parameter "B" in the Arrhenius equation
    invovlved in the GL model from data for a specific temperature
    """
    M = estimate_tinc(df.copy(),thresh = thresh,method = method)
    with warnings.catch_warnings(action ='ignore'):
        df = df.loc[df['X'] <= 1 - eps,:]
        df.loc[df['X'].to_numpy() <=  0,:] = eps
        df.loc[:,'time'] -= M
   
    
    a = df['X'].to_numpy()**(-nu) - 1 
    index = a > 0
    return -1/df['time'].to_numpy()[index]*np.log(a[index])

def get_gl_rate_estimate(df: pd.DataFrame,
                         nu: float,
                        thresh: float = 0.02,
                        method: str = 'first',
                        eps: float = 1e-3,
                        _exponent = 1.):
    """ 
    estimate the parameter "B" in the Arrhenius equation
    invovlved in the GL model
    """
    temperatures = df['temperature'].unique()
    B = []
    temps = []
    for T in temperatures:
        B.append(
            estimate_gl_rate(df.loc[df['temperature'] == T],nu,eps = eps,thresh = thresh,method = method)
            ) 
        temps.append(np.array([T]*B[-1].shape[0]))
        
    return pd.DataFrame(
        np.array([np.concatenate(temps)**_exponent,np.concatenate(B)]).T,
        columns = ['temperature','B'])

def estimate_gl_rate_function(data_set: List[pd.DataFrame],
                              nu: float,
                              thresh: float = 0.02,
                              method: str = 'first',
                              eps: float = 1e-3,
                              est_order = 2,
                              _exponent = 1.) -> Tuple[ArrheniusProcess,pd.DataFrame]:
    """ 
    fit the Arrhenius equation to the data
    """
    B = []
    for data in data_set:
        B.append(
            get_gl_rate_estimate(data.copy(),nu,eps = eps,thresh = thresh,method = method,
                                 _exponent = _exponent)
        )
    
    B = pd.concat(B)
    B = B.loc[B['B'] > 0]
    res = estimate_arrhenius(B['temperature'].to_numpy(),
                                        B['B'].to_numpy(),est_order)
    return res,B

def ci_plot(ax: plt.Axes,
            x: np.ndarray,
            yhat: np.ndarray,
            lower: np.ndarray,
            upper: np.ndarray,
            color: str = 'k',
            alpha: float = 0.2,
            ls = '-',
            ci_ls = '--',
            fill = True):
    """
    plot the confidence interval for the linear regression
    """
    ax.plot(x,yhat,color = color,lw = 1.,ls = ls)
    ax.plot(x,lower,color = color,lw = 0.75,ls = ci_ls)
    ax.plot(x,upper,color = color,lw = 0.75,ls = ci_ls)
    if fill:
        ax.fill_between(x,lower,upper,color = color,alpha = alpha)
    return ax

def plot_and_estimate_arrhenius_multiple(data_sets: List[pd.DataFrame],
                                         estimate_value_func: Callable,
                                         estimate_model_func: Callable,
                                         estimate_column: str,
                                         estimate_ylabel: str,
                                         iterable_kwargs: List[dict],
                                         iterable_args = None,
                                         markers = ['h','h','D','D','s','o','^'],
                                         colors = None,
                                         labels = None,
                                         **estimate_kwargs) -> Tuple[plt.Figure,plt.Axes]:

    """
    this was getting repetative to do essentially the same thing for each Arrhenius process
    so this function is a wrapper for the plotting and estimation of the Arrhenius process. 

    It's defintitely not very general, but is efffecive for the purposes of this project
    """
    #basic formatting of plot
    if colors is None:
        colors = plt.get_cmap('Dark2')(np.linspace(0.2,0.8,len(data_sets)))

    if labels is None:
        labels = [None]*len(data_sets)

    if iterable_args is None:
        iterable_args = [()]*len(iterable_kwargs)
    fig,axes = plt.subplots(figsize = (9,4.),ncols = 2)

    #iterate over the fitting/estimation methodologies
    for more_args,more_kwargs,ax in zip(iterable_args,iterable_kwargs,axes):
        for key in more_kwargs:
            estimate_kwargs[key] = more_kwargs[key]
   
        setup_axis_default(ax)
        ax.set_title(r'Method: ' + estimate_kwargs['method'],fontsize = 13)
        ax.set_xlabel(r'$1/T$ [K$^{-1} \times 10^{-4}$]')

        ## scatter plot full data set
        for i,data in enumerate(data_sets):
            estimated_value = estimate_value_func(data,*more_args,**estimate_kwargs)
            estimated_value = estimated_value.loc[estimated_value[estimate_column] > 0]
            ax.scatter(1/estimated_value['temperature']*1e4,np.log(estimated_value[estimate_column]),
                       facecolor = colors[i],edgecolor = 'k',
                       lw = 1.0,s = 30,marker = markers[i],label = labels[i])

        #estimate arrhenius parameters
        for order,ls in zip([2,3],['-','--']):
            result,_ = estimate_model_func(data_sets,*more_args,est_order = order,**estimate_kwargs)

            model_fmt = 'y = {:.4f} + {:.4f}x' if len(result) == 2 else 'y = {:.4f} + {:.4f}x_1^{:.4f}'
            model_fmt = model_fmt.format(*result.params)

            #plot the regression
            xplot = np.linspace(950,2000,100) + 273.15 
            if len(result) == 2:
                print(f'linear model using {estimate_kwargs['method']}, order = {order} point estimation' + ': ' + model_fmt) 
                yhat = result.log_predict(xplot)
                ci_yhat = result.ols_results.get_prediction(result.tform(xplot)).conf_int(alpha = 0.05)
                ci_plot(ax,1/xplot*1e4,yhat,*ci_yhat.T,ls = ls,ci_ls = ':',alpha = 0.05)
            else:
                print(f'non-linear model using {estimate_kwargs['method']}, order = {order} point estimation' + ': ' + model_fmt) 
                yhat = result.log_predict(xplot)
                ax.plot(1/xplot*1e4,yhat,ls = ls,lw = 1,color = 'k')

    axes[0].set_ylabel(estimate_ylabel)
    return fig,axes

def plot_and_estimate_arrhenius_single(data: pd.DataFrame,
                                       estimate_value_func: Callable,
                                       estimate_model_func: Callable,
                                       estimate_column: str,
                                       model_order: int,
                                       ax: plt.Axes,
                                       color: Any,
                                       marker: str,
                                       *estimate_args,
                                       label: str = None,
                                       ls = '-',
                                       **estimate_kwargs) -> Tuple[ArrheniusProcess,plt.Axes]:

    """
    reduce the repetative code for plotting and estimating the Arrhenius process
    """
    estimate_value = estimate_value_func(data,*estimate_args,**estimate_kwargs)
    estimate_value = estimate_value.loc[estimate_value[estimate_column] > 0]

    #use simple linear regression to estimate the incubation/starting time
    result,_ = estimate_model_func([data],est_order = model_order,*estimate_args,**estimate_kwargs)
    model_fmt = 'y = {:.4f} + {:.4f}x' if len(result) == 2 else 'y = {:.4f} + {:.4f}x_1^{:.4f}'
    model_fmt = model_fmt.format(*result.params)

    y = np.log(estimate_value[estimate_column].to_numpy())
    yhat_ = result.log_predict(estimate_value['temperature'].to_numpy())

    SS_T = np.sum((y - np.mean(y))**2)
    SS_R = np.sum((y - yhat_)**2)
    R2_adj = 1 - SS_R/SS_T*(data.shape[0] - 1)/(data.shape[0] - len(result) - 1)
    print(f'method: {estimate_kwargs['method']}, order: {model_order}' + ' | ' + model_fmt + ' | R^2_adj: {0:.4f}'.format(R2_adj))

    #plot the linear regression
    xplot = np.linspace(950,2000,100) + 273.15
    yhat = result.log_predict(xplot)

    ax.scatter(1/estimate_value['temperature']*1e4,np.log(estimate_value[estimate_column]),
                facecolor = color,edgecolor = 'k',
                lw = 1.0,s = 30,marker = marker,label = label)
    ax.plot(1/xplot*1e4,yhat,color = 'k',lw = 0.5,ls = ls)

    return result,ax

# %% [markdown]
# ### Gather Full Dataset
# and set-up variables to help with managing different data sets

# %%
# data files to examine
data_file = [DATA_DIR.joinpath(file) for file in ['alfonso_data/highly_rolled.csv',
             'alfonso_data/moderate_roll.csv',
             'richou_data/batch_a_data.csv',
             'richou_data/batch_b_data.csv',
             'yu_data/data.csv',
             'shah_data/binned_temperature_data.csv']
]

#formatting for the plot
labels = ['Lopez et al. (2015) - HR',
          'Lopez et al. (2015) - MR',
          'Richou et al. (2020) - Batch A',
          'Richou et al. (2020) - Batch B',
          'Yu et al. (2017)',
          'Shah et al. (2021)']

markers = ['h','h','D','D','s','o']
multiplier = [3600,3600,1,1,3600,1]

#load the data
dataset = []
for i,file in enumerate(data_file):
    data = pd.read_csv(file,index_col = 0)
    data['temperature'] += 273.15
    data['time'] *= multiplier[i]
    dataset.append(data)

colors = plt.get_cmap('Dark2')(np.linspace(0.2,0.8,len(dataset)))

# %% [markdown]
# ### Visualizing Full Data Set
#
# Below is an estimate of the above linear model for incubation/starting time across all the considered data. The range of the estimated starting times don't seem to effect the model fit that much, however this is likely because the inter-study variation is much greater than the variation due to estimated starting times.

# %%
fig,ax = plot_and_estimate_arrhenius_multiple(dataset,
                                              get_tinc_estimates,
                                             estimate_incubation_time_function,
                                             'tinc',
                                             r'$t_{\text{inc}}$ [s]',
                                            [{'method':'first','thresh': 0.005},{'method':'last','thresh':0.02}],
                                            labels = labels)

fig.tight_layout(pad = 0.1)
# Out:
# linear model using first, order = 2 point estimation: y = 4.3795 + 5846.2157x
# non-linear model using first, order = 3 point estimation: y = -44.2320 + 109.2243x_1^0.1000
# linear model using last, order = 2 point estimation: y = 4.6958 + 5631.8384x
# non-linear model using last, order = 3 point estimation: y = -42.3459 + 105.6615x_1^0.1000

# %% [markdown]
# ### Visualizing Independent Fits
#
# We can get a better estimate of the "spread" in the incubation time/starting time by fitting models to each data set independently. We can see that the incubation estimation procedure has a more marked effect on the estimated model.
#
# We can also see that the additional term in the model can lead to some pretty wild extrapolations if the temperature range over the data isn't sufficiently large.

# %%
import pickle

fig,axes = plt.subplots(figsize = (9,8.),ncols = 2,nrows = 2)

for i,data in enumerate(dataset):
    print(labels[i] + '\n')

    for estimate_kwargs,k in zip([{'method':'first','thresh':0.005},{'method':'last','thresh':0.02}],range(2)):
        for j,order, ls in zip(range(2),[2,3],['-','--']):
            result,_ = plot_and_estimate_arrhenius_single(data,
                                               get_tinc_estimates,
                                               estimate_incubation_time_function,
                                               'tinc',
                                               order,
                                               axes[j,k],
                                               color = colors[i],
                                               marker = markers[i],
                                               label = labels[i],
                                               ls = ls,
                                              **estimate_kwargs)
            
            with open(MODEL_PATH.joinpath(f'log_tinc_{labels[i]}_{estimate_kwargs['method']}_{order}.pkl'),'wb') as f:
                pickle.dump(result,f)

        print('-----------------------------------')
    print('-----------------------------------\n')

for method,i in zip(['first','last'],range(2)):
    for j in range(2):
        setup_axis_default(axes[i,j])
    
    axes[0,i].set_title(r'Method: ' + method,fontsize = 12)
    axes[1,i].set_xlabel(r'$1/T$ [K$^{-1} \times 10^{-4}$]')
    axes[i,0].set_ylabel(r'$\ln(t_{inc}) / ln(M)$')

fig.tight_layout()
# Out:
# Lopez et al. (2015) - HR
#
# method: first, order: 2 | y = -19.7205 + 44220.0385x | R^2_adj: 0.9683
# method: first, order: 3 | y = -4.4479 + 31377920.7358x_1^1.9974 | R^2_adj: 0.9681
# -----------------------------------
# method: last, order: 2 | y = -19.2013 + 43600.5116x | R^2_adj: 0.9831
# method: last, order: 3 | y = -0.9252 + 1249931192.6286x_1^2.5389 | R^2_adj: 0.9835
# -----------------------------------
# -----------------------------------
#
# Lopez et al. (2015) - MR
#
# method: first, order: 2 | y = -33.3526 + 68737.3158x | R^2_adj: 0.9829
# method: first, order: 3 | y = -15.5852 + 4843932.5918x_1^1.6491 | R^2_adj: 0.9828
# -----------------------------------
# method: last, order: 2 | y = -33.3124 + 68704.5369x | R^2_adj: 0.9834
# method: last, order: 3 | y = -13.9244 + 9788999.5596x_1^1.7536 | R^2_adj: 0.9833
# -----------------------------------
# -----------------------------------
#
# Richou et al. (2020) - Batch A
#
# method: first, order: 2 | y = -21.4918 + 47112.2744x | R^2_adj: 0.7555
# method: first, order: 3 | y = -262.0623 + 564.5031x_1^0.1000 | R^2_adj: 0.7546
# -----------------------------------
# method: last, order: 2 | y = -23.4349 + 50986.6916x | R^2_adj: 0.8321
# method: last, order: 3 | y = -283.2745 + 609.8386x_1^0.1000 | R^2_adj: 0.8306
# -----------------------------------
# -----------------------------------
#
# Richou et al. (2020) - Batch B
#
# method: first, order: 2 | y = -21.7161 + 50248.2008x | R^2_adj: 0.9614
# method: first, order: 3 | y = -4.2833 + 61217309409.8072x_1^3.0000 | R^2_adj: 0.9695
# -----------------------------------
# method: last, order: 2 | y = -17.0474 + 41827.8048x | R^2_adj: 0.9269
# method: last, order: 3 | y = -2.5845 + 51296669495.6830x_1^3.0000 | R^2_adj: 0.9473
# -----------------------------------
# -----------------------------------
#
# Yu et al. (2017)
#
# method: first, order: 2 | y = -14.2826 + 34383.1823x | R^2_adj: 0.9482
# method: first, order: 3 | y = -214.8306 + 464.3652x_1^0.1000 | R^2_adj: 0.9496
# -----------------------------------
# method: last, order: 2 | y = -13.6558 + 33484.0547x | R^2_adj: 0.9511
# method: last, order: 3 | y = -208.9269 + 452.1541x_1^0.1000 | R^2_adj: 0.9522
# -----------------------------------
# -----------------------------------
#
# Shah et al. (2021)
#
# method: first, order: 2 | y = 15.5913 + -10236.2565x | R^2_adj: 0.9195
# method: first, order: 3 | y = 85.3168 + -159.1382x_1^0.1000 | R^2_adj: 0.9400
# -----------------------------------
# method: last, order: 2 | y = 15.9838 + -10443.6939x | R^2_adj: 0.9461
# method: last, order: 3 | y = 86.6732 + -161.4384x_1^0.1000 | R^2_adj: 0.9562
# -----------------------------------
# -----------------------------------

# %% [markdown]
# ### Estimating the Model for $b$ (JMAK)
#
# Once we have estimated $t_{inc}$ in the JMAK model, this leaves only $n$ and $b$ as we have observations for $X$ as a function of $t$, as demonstrated:
#
# $
# X = 1 - \exp{\left( -b^n (t - t_{inc})^n \right)} \implies b = -\exp{\left(\frac{\ln{\ln{(1 - X)}} - n\ln{(t- t_{inc})}}{n}\right)}
# $
#
# We have some _apriori_ knowledge of $n$ which is dependent upon the shape distribution of the crystals in the materials so that $1 \leq n \leq 3$. Thus, $b$ can be obtained directly from the data.

# %% [markdown]
# ### Visualizing the Full Data Set
# The range in estimated $t_{inc}, n$ has a surprinsingly small effect on the estimated linear model for $b$.

# %%
fig,ax = plot_and_estimate_arrhenius_multiple(dataset,
                                              get_b_estimate,
                                             estimate_b_function,
                                             'b',
                                             r'$\ln{b}$',
                                            [{'method':'first','thresh': 0.005},{'method':'last','thresh':0.02}],
                                            iterable_args= [(1.0,),(3.0,)],
                                            labels = labels)

fig.tight_layout(pad = 0.1)
# Out:
# linear model using first, order = 2 point estimation: y = 7.5587 + -26662.5021x
# non-linear model using first, order = 3 point estimation: y = 162.5421 + -359.1995x_1^0.1000
# linear model using last, order = 2 point estimation: y = 12.7786 + -34963.2652x
# non-linear model using last, order = 3 point estimation: y = 12.6338 + -36545.6392x_1^1.0069

# %% [markdown]
# ### Visualizing Independent Fits
#
# Yu's data appears to be rather anomolous, so we'll omit it from this fit. We can see in some cases that the estimation method for the starting time has some significant impact on the estimated linear model, and certainly there is a rather large inter-data set variation.

# %%
import pickle

fig,axes = plt.subplots(figsize = (9,8.),ncols = 2,nrows = 2)

for i,data in enumerate(dataset):
    print(labels[i] + '\n')
    for estimate_args,estimate_kwargs,k in zip([(1.0,),(3.0,)],[{'method':'first','thresh':0.005},{'method':'last','thresh':0.02}],range(2)):
        for j,order, ls in zip(range(2),[2,3],['-','--']):
            try:
                result,_ = plot_and_estimate_arrhenius_single(data,
                                                get_b_estimate,
                                                estimate_b_function,
                                                'b',
                                                order,
                                                axes[j,k],
                                                colors[i],
                                                markers[i],
                                                *estimate_args,
                                                label = labels[i],
                                                ls = ls,
                                                **estimate_kwargs)
            except RuntimeError as rte:
                print(str(rte))
            
            with open(MODEL_PATH.joinpath(f'/log_b_{labels[i]}_{estimate_kwargs['method']}_{order}.pkl'),'wb') as f:
                pickle.dump(result,f)
                        

        print('-----------------------------------')
    print('-----------------------------------\n')

for method,i in zip(['first','last'],range(2)):
    for j in range(2):
        setup_axis_default(axes[i,j])
    
    axes[0,i].set_title(r'Method: ' + method,fontsize = 12)
    axes[1,i].set_xlabel(r'$1/T$ [K$^{-1} \times 10^{-4}$]')
    axes[i,0].set_ylabel(r'$ln{b}$')

fig.tight_layout()
# Out:
# Lopez et al. (2015) - HR
#
# method: first, order: 2 | y = 14.0543 + -35901.9827x | R^2_adj: 0.4262
# method: first, order: 3 | y = -2.4713 + -25006426668.9299x_1^3.0000 | R^2_adj: 0.4209
# -----------------------------------
# method: last, order: 2 | y = 15.4032 + -37170.4763x | R^2_adj: 0.6068
# method: last, order: 3 | y = -1.6602 + -26036292960.0443x_1^3.0000 | R^2_adj: 0.6107
# -----------------------------------
# -----------------------------------
#
# Lopez et al. (2015) - MR
#
# method: first, order: 2 | y = 32.9058 + -67686.6556x | R^2_adj: 0.9646
# method: first, order: 3 | y = 3.3915 + -52297758598.1739x_1^3.0000 | R^2_adj: 0.9705
# -----------------------------------
# method: last, order: 2 | y = 32.4137 + -67011.9065x | R^2_adj: 0.9214
# method: last, order: 3 | y = 3.1289 + -51568184873.5435x_1^3.0000 | R^2_adj: 0.9214
# -----------------------------------
# -----------------------------------
#
# Richou et al. (2020) - Batch A
#
# method: first, order: 2 | y = 28.0551 + -62774.0460x | R^2_adj: 0.8339
# method: first, order: 3 | y = 5.7337 + -8612088831.9284x_1^2.7149 | R^2_adj: 0.8298
# -----------------------------------
# method: last, order: 2 | y = 18.8501 + -45671.5393x | R^2_adj: 0.5654
# method: last, order: 3 | y = 250.9442 + -544.8718x_1^0.1000 | R^2_adj: 0.5559
# -----------------------------------
# -----------------------------------
#
# Richou et al. (2020) - Batch B
#
# method: first, order: 2 | y = 21.4430 + -51908.1657x | R^2_adj: 0.7599
# method: first, order: 3 | y = 266.5519 + -579.7210x_1^0.1000 | R^2_adj: 0.7574
# -----------------------------------
# method: last, order: 2 | y = 19.0561 + -47334.5180x | R^2_adj: 0.7998
# method: last, order: 3 | y = 242.8493 + -529.2334x_1^0.1000 | R^2_adj: 0.7964
# -----------------------------------
# -----------------------------------
#
# Yu et al. (2017)
#
# method: first, order: 2 | y = 1.5337 + -16284.7740x | R^2_adj: 0.5149
# method: first, order: 3 | y = -5.4568 + -12281439837.6864x_1^2.9918 | R^2_adj: 0.4980
# -----------------------------------
# method: last, order: 2 | y = 1.1699 + -16188.7901x | R^2_adj: 0.1014
# method: last, order: 3 | y = -5.7836 + -12954128420.4603x_1^3.0000 | R^2_adj: 0.0700
# -----------------------------------
# -----------------------------------
#
# Shah et al. (2021)
#
# method: first, order: 2 | y = nan + nanx | R^2_adj: nan
# failed to fit fudge factor arrhenius model
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:290: RuntimeWarning: invalid value encountered in subtract
#   SS_T = np.sum((y - np.mean(y))**2)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:290: RuntimeWarning: invalid value encountered in subtract
#   SS_T = np.sum((y - np.mean(y))**2)
# -----------------------------------
# method: last, order: 2 | y = nan + nanx | R^2_adj: nan
# failed to fit fudge factor arrhenius model
# -----------------------------------
# -----------------------------------
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:62: RuntimeWarning: divide by zero encountered in log
#   y = 1./n*np.log(df['time'].to_numpy()**n/np.log(1/(1-df['X'].to_numpy())))
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\1650646857.py:63: RuntimeWarning: divide by zero encountered in divide
#   return 1./np.exp(y)

# %% [markdown]
# ### Estimating the model for $B$ (GL model)
#
# This estimation is straightforward, provided that $X$ is defined as $X_0$ the threshold when $t = M$ and $\nu$ can be obtained directly as:
#
# $$
# \nu = \frac{\ln{2}}{ \ln{X}_0}
# $$
#
# With $\nu$ known, we can again solve for $B$ to get an explicit expression from the GL function, and estimate its value from the data:
# $$
# X = \frac{1}{(1 + e^{-B (t - M)})^{1/\nu}} \implies B  = \frac{1}{M -t} \ln{\left(\frac{1}{X^{1/\nu} - 1}\right)}\\
# $$
#
# I'll note however, that $X_0$ was assumed, and $\nu$ could actually be lower or higher, in order to not limit ourselves, we'll choose $\nu \in [1e-3,5e-2] $ approximately.

# %% [markdown]
# ### Visualizing the Full Data Set
#
# This looks pretty similar to the estimate for $b$ in the JMAK model, which makes sense as they are both the "rate" parameters in the respective equations.

# %%
fig,ax = plot_and_estimate_arrhenius_multiple(dataset,
                                              get_gl_rate_estimate,
                                             estimate_gl_rate_function,
                                             'B',
                                             r'$ln{B}$',
                                            [{'method':'first','thresh': 0.005},{'method':'last','thresh':0.02}],
                                            iterable_args= [(1e-3,),(5e-2,)],
                                            labels = labels)

fig.tight_layout(pad = 0.1)
# Out:
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# linear model using first, order = 2 point estimation: y = nan + nanx
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 fig,ax = plot_and_estimate_arrhenius_multiple(dataset,
#       2                                               get_gl_rate_estimate,
#       3                                              estimate_gl_rate_function,
#       4                                              'B',
#       5                                              r'$ln{B}$',
#       6                                             [{'method':'first','thresh': 0.005},{'method':'last','thresh':0.02}],
#       7                                             iterable_args= [(1e-3,),(5e-2,)],
#       8                                             labels = labels)
#      10 fig.tight_layout(pad = 0.1)
#
# Cell In[30], line 243, in plot_and_estimate_arrhenius_multiple(data_sets, estimate_value_func, estimate_model_func, estimate_column, estimate_ylabel, iterable_kwargs, iterable_args, markers, colors, labels, **estimate_kwargs)
#     241 #estimate arrhenius parameters
#     242 for order,ls in zip([2,3],['-','--']):
# --> 243     result,_ = estimate_model_func(data_sets,*more_args,est_order = order,**estimate_kwargs)
#     245     model_fmt = 'y = {:.4f} + {:.4f}x' if len(result) == 2 else 'y = {:.4f} + {:.4f}x_1^{:.4f}'
#     246     model_fmt = model_fmt.format(*result.params)
#
# Cell In[30], line 171, in estimate_gl_rate_function(data_set, nu, thresh, method, eps, est_order, _exponent)
#     169 B = pd.concat(B)
#     170 B = B.loc[B['B'] > 0]
# --> 171 res = estimate_arrhenius(B['temperature'].to_numpy(),
#     172                                     B['B'].to_numpy(),est_order)
#     173 return res,B
#
# Cell In[30], line 24, in estimate_arrhenius(T, z, est_order)
#      22     return LogLinearArrhenius().fit(T,z)
#      23 else:
# ---> 24     return FudgeFactorArrhenius().fit(T,z,1.0,beta_bounds = (0.1,3.0))
#
# File e:\ORNL Collaboration\System Design\ASME Code\modeling_tungsten\recrystallization\data_exploration\..\common_util.py:401, in FudgeFactorArrhenius.fit(self, x, y, beta_init, beta_bounds)
#     399     self.params[2] = opt_result.x
#     400 else:
# --> 401     raise RuntimeError('failed to fit fudge factor arrhenius model')
#     403 self.ols_results = OLS(self.logy,self.tform(x)).fit()
#     404 self.params[:-1]= self.ols_results.params.squeeze()
#
# RuntimeError: failed to fit fudge factor arrhenius model

# %% [markdown]
# ### Visualizing Independent Fits
#
# And the individual fits are plotted below.

# %%
import pickle

fig,axes = plt.subplots(figsize = (9,8.),ncols = 2,nrows = 2)

for i,data in enumerate(dataset):
    print(labels[i] + '\n')
    for estimate_args,estimate_kwargs,k in zip([(1e-3,),(5e-2,)],[{'method':'first','thresh':0.005},{'method':'last','thresh':0.02}],range(2)):
        for j,order, ls in zip(range(2),[2,3],['-','--']):
            result,_ = plot_and_estimate_arrhenius_single(data,
                                               get_gl_rate_estimate,
                                               estimate_gl_rate_function,
                                               'B',
                                               order,
                                               axes[j,k],
                                               colors[i],
                                               markers[i],
                                               *estimate_args,
                                               label = labels[i],
                                               ls = ls,
                                              **estimate_kwargs)
            
            with open(MODEL_PATH.joinpath(f'log_B_{labels[i]}_{estimate_kwargs['method']}_{order}.pkl'),'wb') as f:
                pickle.dump(result,f)


        print('-----------------------------------')
    print('-----------------------------------\n')

for method,i in zip(['first','last'],range(2)):
    for j in range(2):
        setup_axis_default(axes[i,j])
    
    axes[0,i].set_title(r'Method: ' + method,fontsize = 12)
    axes[1,i].set_xlabel(r'$1/T$ [K$^{-1} \times 10^{-4}$]')
    axes[i,0].set_ylabel(r'$ln{B}$')

fig.tight_layout()
# Out:
# Lopez et al. (2015) - HR
#
# method: first, order: 2 | y = 19.4655 + -40002.4674x | R^2_adj: 0.4763
# method: first, order: 3 | y = 1.0571 + -27876969811.1494x_1^3.0000 | R^2_adj: 0.4724
# -----------------------------------
# method: last, order: 2 | y = 16.8134 + -37142.1194x | R^2_adj: 0.6005
# method: last, order: 3 | y = -0.2357 + -26020781612.5874x_1^3.0000 | R^2_adj: 0.6045
# -----------------------------------
# -----------------------------------
#
# Lopez et al. (2015) - MR
#
# method: first, order: 2 | y = 38.7135 + -73194.1132x | R^2_adj: 0.8511
# method: first, order: 3 | y = 471.0731 + -999.9191x_1^0.1000 | R^2_adj: 0.8486
# -----------------------------------
# method: last, order: 2 | y = 33.9959 + -67300.4563x | R^2_adj: 0.9320
# method: last, order: 3 | y = 4.5867 + -51795807241.3623x_1^3.0000 | R^2_adj: 0.9324
# -----------------------------------
# -----------------------------------
#
# Richou et al. (2020) - Batch A
#
# method: first, order: 2 | y = 17.0474 + -38552.6515x | R^2_adj: 0.3371
# method: first, order: 3 | y = 212.9080 + -459.8218x_1^0.1000 | R^2_adj: 0.3203
# -----------------------------------
# method: last, order: 2 | y = 20.3180 + -45802.4627x | R^2_adj: 0.5454
# method: last, order: 3 | y = 253.1981 + -546.6890x_1^0.1000 | R^2_adj: 0.5359
# -----------------------------------
# -----------------------------------
#
# Richou et al. (2020) - Batch B
#
# method: first, order: 2 | y = 23.3958 + -51470.7787x | R^2_adj: 0.6672
# method: first, order: 3 | y = 266.3574 + -574.6618x_1^0.1000 | R^2_adj: 0.6606
# -----------------------------------
# method: last, order: 2 | y = 20.5841 + -47622.4409x | R^2_adj: 0.8009
# method: last, order: 3 | y = 245.7805 + -532.5419x_1^0.1000 | R^2_adj: 0.7978
# -----------------------------------
# -----------------------------------
#
# Yu et al. (2017)
#
# method: first, order: 2 | y = 3.1940 + -16234.4194x | R^2_adj: 0.0789
# method: first, order: 3 | y = -3.7756 + -13003504159.9001x_1^3.0000 | R^2_adj: 0.0469
# -----------------------------------
# method: last, order: 2 | y = 2.7560 + -16490.8860x | R^2_adj: 0.1251
# method: last, order: 3 | y = -4.3260 + -13200696678.0648x_1^3.0000 | R^2_adj: 0.0948
# -----------------------------------
# -----------------------------------
#
# Shah et al. (2021)
#
# method: first, order: 2 | y = nan + nanx | R^2_adj: nan
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:290: RuntimeWarning: invalid value encountered in subtract
#   SS_T = np.sum((y - np.mean(y))**2)
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# C:\Users\mlanahan3\AppData\Local\Temp\ipykernel_152436\3357132597.py:127: RuntimeWarning: divide by zero encountered in divide
#   return -1/df['time'].to_numpy()[index]*np.log(a[index])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[36], line 9
#       7 for estimate_args,estimate_kwargs,k in zip([(1e-3,),(5e-2,)],[{'method':'first','thresh':0.005},{'method':'last','thresh':0.02}],range(2)):
#       8     for j,order, ls in zip(range(2),[2,3],['-','--']):
# ----> 9         result,_ = plot_and_estimate_arrhenius_single(data,
#      10                                            get_gl_rate_estimate,
#      11                                            estimate_gl_rate_function,
#      12                                            'B',
#      13                                            order,
#      14                                            axes[j,k],
#      15                                            colors[i],
#      16                                            markers[i],
#      17                                            *estimate_args,
#      18                                            label = labels[i],
#      19                                            ls = ls,
#      20                                           **estimate_kwargs)
#      22         with open(MODEL_PATH.joinpath(f'log_B_{labels[i]}_{estimate_kwargs['method']}_{order}.pkl'),'wb') as f:
#      23             pickle.dump(result,f)
#
# Cell In[30], line 283, in plot_and_estimate_arrhenius_single(data, estimate_value_func, estimate_model_func, estimate_column, model_order, ax, color, marker, label, ls, *estimate_args, **estimate_kwargs)
#     280 estimate_value = estimate_value.loc[estimate_value[estimate_column] > 0]
#     282 #use simple linear regression to estimate the incubation/starting time
# --> 283 result,_ = estimate_model_func([data],est_order = model_order,*estimate_args,**estimate_kwargs)
#     284 model_fmt = 'y = {:.4f} + {:.4f}x' if len(result) == 2 else 'y = {:.4f} + {:.4f}x_1^{:.4f}'
#     285 model_fmt = model_fmt.format(*result.params)
#
# Cell In[30], line 171, in estimate_gl_rate_function(data_set, nu, thresh, method, eps, est_order, _exponent)
#     169 B = pd.concat(B)
#     170 B = B.loc[B['B'] > 0]
# --> 171 res = estimate_arrhenius(B['temperature'].to_numpy(),
#     172                                     B['B'].to_numpy(),est_order)
#     173 return res,B
#
# Cell In[30], line 24, in estimate_arrhenius(T, z, est_order)
#      22     return LogLinearArrhenius().fit(T,z)
#      23 else:
# ---> 24     return FudgeFactorArrhenius().fit(T,z,1.0,beta_bounds = (0.1,3.0))
#
# File e:\ORNL Collaboration\System Design\ASME Code\modeling_tungsten\recrystallization\data_exploration\..\common_util.py:401, in FudgeFactorArrhenius.fit(self, x, y, beta_init, beta_bounds)
#     399     self.params[2] = opt_result.x
#     400 else:
# --> 401     raise RuntimeError('failed to fit fudge factor arrhenius model')
#     403 self.ols_results = OLS(self.logy,self.tform(x)).fit()
#     404 self.params[:-1]= self.ols_results.params.squeeze()
#
# RuntimeError: failed to fit fudge factor arrhenius model
